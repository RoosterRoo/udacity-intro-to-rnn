# %% [markdown]
# # Anna KaRNNa
#
# In this notebook, I'll build a character-wise RNN trained on Anna Karenina, one of my all-time favorite books. It'll be able to generate new text based on the text from the book.
#
# This network is based off of Andrej Karpathy's [post on RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/) and [implementation in Torch](https://github.com/karpathy/char-rnn). Also, some information [here at r2rt](http://r2rt.com/recurrent-neural-networks-in-tensorflow-ii.html) and from [Sherjil Ozair](https://github.com/sherjilozair/char-rnn-tensorflow) on GitHub. Below is the general architecture of the character-wise RNN.
#
# <img src="assets/charseq.jpeg" width="500">

# %%
import time
from collections import namedtuple

import numpy as np
import tensorflow as tf

# %% [markdown]
# First we'll load the text file and convert it into integers for our network to use. Here I'm creating a couple dictionaries to convert the characters to and from integers. Encoding the characters as integers makes it easier to use as input in the network.

# %%
with open('anna.txt', 'r') as f:
    text=f.read()
vocab = set(text)
vocab_to_int = {c: i for i, c in enumerate(vocab)}
int_to_vocab = dict(enumerate(vocab))
encoded = np.array([vocab_to_int[c] for c in text], dtype=np.int32)

# %% [markdown]
# Let's check out the first 100 characters, make sure everything is peachy. According to the [American Book Review](http://americanbookreview.org/100bestlines.asp), this is the 6th best first line of a book ever.

# %%
text[:100]
# Out:
# 'Chapter 1\n\n\nHappy families are all alike; every unhappy family is unhappy in its own\nway.\n\nEverythin'

# %% [markdown]
# And we can see the characters encoded as integers.

# %%
encoded[:100]
# Out:
# array([73,  2, 81, 11,  6, 67, 33, 23, 60, 10, 10, 10, 69, 81, 11, 11, 56,
#        23, 82, 81,  7, 55, 18, 55, 67, 27, 23, 81, 33, 67, 23, 81, 18, 18,
#        23, 81, 18, 55, 16, 67, 74, 23, 67, 64, 67, 33, 56, 23, 46, 15,  2,
#        81, 11, 11, 56, 23, 82, 81,  7, 55, 18, 56, 23, 55, 27, 23, 46, 15,
#         2, 81, 11, 11, 56, 23, 55, 15, 23, 55,  6, 27, 23,  8, 30, 15, 10,
#        30, 81, 56,  0, 10, 10, 58, 64, 67, 33, 56,  6,  2, 55, 15], dtype=int32)

# %% [markdown]
# Since the network is working with individual characters, it's similar to a classification problem in which we are trying to predict the next character from the previous text.  Here's how many 'classes' our network has to pick from.

# %%
len(vocab)
# Out:
# 83

# %% [markdown]
# ## Making training mini-batches
#
# Here is where we'll make our mini-batches for training. Remember that we want our batches to be multiple sequences of some desired number of sequence steps. Considering a simple example, our batches would look like this:
#
# <img src="assets/sequence_batching@1x.png" width=500px>
#
#
# <br>
# We have our text encoded as integers as one long array in `encoded`. Let's create a function that will give us an iterator for our batches. I like using [generator functions](https://jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/) to do this. Then we can pass `encoded` into this function and get our batch generator.
#
# The first thing we need to do is discard some of the text so we only have completely full batches. Each batch contains $N \times M$ characters, where $N$ is the batch size (the number of sequences) and $M$ is the number of steps. Then, to get the number of batches we can make from some array `arr`, you divide the length of `arr` by the batch size. Once you know the number of batches and the batch size, you can get the total number of characters to keep.
#
# After that, we need to split `arr` into $N$ sequences. You can do this using `arr.reshape(size)` where `size` is a tuple containing the dimensions sizes of the reshaped array. We know we want $N$ sequences (`n_seqs` below), let's make that the size of the first dimension. For the second dimension, you can use `-1` as a placeholder in the size, it'll fill up the array with the appropriate data for you. After this, you should have an array that is $N \times (M * K)$ where $K$ is the number of batches.
#
# Now that we have this array, we can iterate through it to get our batches. The idea is each batch is a $N \times M$ window on the array. For each subsequent batch, the window moves over by `n_steps`. We also want to create both the input and target arrays. Remember that the targets are the inputs shifted over one character. You'll usually see the first input character used as the last target character, so something like this:
# ```python
# y[:, :-1], y[:, -1] = x[:, 1:], x[:, 0]
# ```
# where `x` is the input batch and `y` is the target batch.
#
# The way I like to do this window is use `range` to take steps of size `n_steps` from $0$ to `arr.shape[1]`, the total number of steps in each sequence. That way, the integers you get from `range` always point to the start of a batch, and each window is `n_steps` wide.

# %%
def get_batches(arr, n_seqs, n_steps):
    '''Create a generator that returns batches of size
       n_seqs x n_steps from arr.
       
       Arguments
       ---------
       arr: Array you want to make batches from
       n_seqs: Batch size, the number of sequences per batch
       n_steps: Number of sequence steps per batch
    '''
    # Get the number of characters per batch and number of batches we can make
    characters_per_batch = n_seqs * n_steps
    n_batches = len(arr)//characters_per_batch
    
    # Keep only enough characters to make full batches
    arr = arr[:n_batches * characters_per_batch]
    
    # Reshape into n_seqs rows
    arr = arr.reshape((n_seqs, -1))
    
    for n in range(0, arr.shape[1], n_steps):
        # The features
        x = arr[:, n:n+n_steps]
        # The targets, shifted by one
        y = np.zeros_like(x)
        y[:, :-1], y[:, -1] = x[:, 1:], x[:, 0]
        yield x, y

# %% [markdown]
# Now I'll make my data sets and we can check out what's going on here. Here I'm going to use a batch size of 10 and 50 sequence steps.

# %%
batches = get_batches(encoded, 10, 50)
x, y = next(batches)

# %%
print('x\n', x[:10, :10])
print('\ny\n', y[:10, :10])
# Out:
# x
#  [[73  2 81 11  6 67 33 23 60 10]
#  [23 81  7 23 15  8  6 23 80  8]
#  [64 55 15  0 10 10 70 19 67 27]
#  [15 23 44 46 33 55 15 80 23  2]
#  [23 55  6 23 55 27 40 23 27 55]
#  [23 65  6 23 30 81 27 10  8 15]
#  [ 2 67 15 23 42  8  7 67 23 82]
#  [74 23 79 46  6 23 15  8 30 23]
#  [ 6 23 55 27 15 28  6  0 23 37]
#  [23 27 81 55 44 23  6  8 23  2]]
#
# y
#  [[ 2 81 11  6 67 33 23 60 10 10]
#  [81  7 23 15  8  6 23 80  8 55]
#  [55 15  0 10 10 70 19 67 27 40]
#  [23 44 46 33 55 15 80 23  2 55]
#  [55  6 23 55 27 40 23 27 55 33]
#  [65  6 23 30 81 27 10  8 15 18]
#  [67 15 23 42  8  7 67 23 82  8]
#  [23 79 46  6 23 15  8 30 23 27]
#  [23 55 27 15 28  6  0 23 37  2]
#  [27 81 55 44 23  6  8 23  2 67]]

# %% [markdown]
# If you implemented `get_batches` correctly, the above output should look something like
# ```
# x
#  [[55 63 69 22  6 76 45  5 16 35]
#  [ 5 69  1  5 12 52  6  5 56 52]
#  [48 29 12 61 35 35  8 64 76 78]
#  [12  5 24 39 45 29 12 56  5 63]
#  [ 5 29  6  5 29 78 28  5 78 29]
#  [ 5 13  6  5 36 69 78 35 52 12]
#  [63 76 12  5 18 52  1 76  5 58]
#  [34  5 73 39  6  5 12 52 36  5]
#  [ 6  5 29 78 12 79  6 61  5 59]
#  [ 5 78 69 29 24  5  6 52  5 63]]
#
# y
#  [[63 69 22  6 76 45  5 16 35 35]
#  [69  1  5 12 52  6  5 56 52 29]
#  [29 12 61 35 35  8 64 76 78 28]
#  [ 5 24 39 45 29 12 56  5 63 29]
#  [29  6  5 29 78 28  5 78 29 45]
#  [13  6  5 36 69 78 35 52 12 43]
#  [76 12  5 18 52  1 76  5 58 52]
#  [ 5 73 39  6  5 12 52 36  5 78]
#  [ 5 29 78 12 79  6 61  5 59 63]
#  [78 69 29 24  5  6 52  5 63 76]]
#  ```
#  although the exact numbers will be different. Check to make sure the data is shifted over one step for `y`.

# %% [markdown]
# ## Building the model
#
# Below is where you'll build the network. We'll break it up into parts so it's easier to reason about each bit. Then we can connect them up into the whole network.
#
# <img src="assets/charRNN.png" width=500px>
#
#
# ### Inputs
#
# First off we'll create our input placeholders. As usual we need placeholders for the training data and the targets. We'll also create a placeholder for dropout layers called `keep_prob`.

# %%
def build_inputs(batch_size, num_steps):
    ''' Define placeholders for inputs, targets, and dropout 
    
        Arguments
        ---------
        batch_size: Batch size, number of sequences per batch
        num_steps: Number of sequence steps in a batch
        
    '''
    # Declare placeholders we'll feed into the graph
    inputs = tf.placeholder(tf.int32, [batch_size, num_steps], name='inputs')
    targets = tf.placeholder(tf.int32, [batch_size, num_steps], name='targets')
    
    # Keep probability placeholder for drop out layers
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    
    return inputs, targets, keep_prob

# %% [markdown]
# ### LSTM Cell
#
# Here we will create the LSTM cell we'll use in the hidden layer. We'll use this cell as a building block for the RNN. So we aren't actually defining the RNN here, just the type of cell we'll use in the hidden layer.
#
# We first create a basic LSTM cell with
#
# ```python
# lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
# ```
#
# where `num_units` is the number of units in the hidden layers in the cell. Then we can add dropout by wrapping it with
#
# ```python
# tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
# ```
# You pass in a cell and it will automatically add dropout to the inputs or outputs. Finally, we can stack up the LSTM cells into layers with [`tf.contrib.rnn.MultiRNNCell`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/rnn/MultiRNNCell). With this, you pass in a list of cells and it will send the output of one cell into the next cell. Previously with TensorFlow 1.0, you could do this
#
# ```python
# tf.contrib.rnn.MultiRNNCell([cell]*num_layers)
# ```
#
# This might look a little weird if you know Python well because this will create a list of the same `cell` object. However, TensorFlow 1.0 will create different weight matrices for all `cell` objects. But, starting with TensorFlow 1.1 you actually need to create new cell objects in the list. To get it to work in TensorFlow 1.1, it should look like
#
# ```python
# def build_cell(num_units, keep_prob):
#     lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
#     drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
#
#     return drop
#
# tf.contrib.rnn.MultiRNNCell([build_cell(num_units, keep_prob) for _ in range(num_layers)])
# ```
#
# Even though this is actually multiple LSTM cells stacked on each other, you can treat the multiple layers as one cell.
#
# We also need to create an initial cell state of all zeros. This can be done like so
#
# ```python
# initial_state = cell.zero_state(batch_size, tf.float32)
# ```
#
# Below, we implement the `build_lstm` function to create these LSTM cells and the initial state.

# %%
def build_lstm(lstm_size, num_layers, batch_size, keep_prob):
    ''' Build LSTM cell.
    
        Arguments
        ---------
        keep_prob: Scalar tensor (tf.placeholder) for the dropout keep probability
        lstm_size: Size of the hidden layers in the LSTM cells
        num_layers: Number of LSTM layers
        batch_size: Batch size

    '''
    ### Build the LSTM Cell
    
    def build_cell(lstm_size, keep_prob):
        # Use a basic LSTM cell
        lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
        
        # Add dropout to the cell
        drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
        return drop
    
    
    # Stack up multiple LSTM layers, for deep learning
    cell = tf.contrib.rnn.MultiRNNCell([build_cell(lstm_size, keep_prob) for _ in range(num_layers)])
    initial_state = cell.zero_state(batch_size, tf.float32)
    
    return cell, initial_state

# %% [markdown]
# ### RNN Output
#
# Here we'll create the output layer. We need to connect the output of the RNN cells to a full connected layer with a softmax output. The softmax output gives us a probability distribution we can use to predict the next character.
#
# If our input has batch size $N$, number of steps $M$, and the hidden layer has $L$ hidden units, then the output is a 3D tensor with size $N \times M \times L$. The output of each LSTM cell has size $L$, we have $M$ of them, one for each sequence step, and we have $N$ sequences. So the total size is $N \times M \times L$.
#
# We are using the same fully connected layer, the same weights, for each of the outputs. Then, to make things easier, we should reshape the outputs into a 2D tensor with shape $(M * N) \times L$. That is, one row for each sequence and step, where the values of each row are the output from the LSTM cells.
#
# One we have the outputs reshaped, we can do the matrix multiplication with the weights. We need to wrap the weight and bias variables in a variable scope with `tf.variable_scope(scope_name)` because there are weights being created in the LSTM cells. TensorFlow will throw an error if the weights created here have the same names as the weights created in the LSTM cells, which they will be default. To avoid this, we wrap the variables in a variable scope so we can give them unique names.

# %%
def build_output(lstm_output, in_size, out_size):
    ''' Build a softmax layer, return the softmax output and logits.
    
        Arguments
        ---------
        
        x: Input tensor
        in_size: Size of the input tensor, for example, size of the LSTM cells
        out_size: Size of this softmax layer
    
    '''

    # Reshape output so it's a bunch of rows, one row for each step for each sequence.
    # That is, the shape should be batch_size*num_steps rows by lstm_size columns
    seq_output = tf.concat(lstm_output, axis=1)
    x = tf.reshape(seq_output, [-1, in_size])
    
    # Connect the RNN outputs to a softmax layer
    with tf.variable_scope('softmax'):
        softmax_w = tf.Variable(tf.truncated_normal((in_size, out_size), stddev=0.1))
        softmax_b = tf.Variable(tf.zeros(out_size))
    
    # Since output is a bunch of rows of RNN cell outputs, logits will be a bunch
    # of rows of logit outputs, one for each step and sequence
    logits = tf.matmul(x, softmax_w) + softmax_b
    
    # Use softmax to get the probabilities for predicted characters
    out = tf.nn.softmax(logits, name='predictions')
    
    return out, logits

# %% [markdown]
# ### Training loss
#
# Next up is the training loss. We get the logits and targets and calculate the softmax cross-entropy loss. First we need to one-hot encode the targets, we're getting them as encoded characters. Then, reshape the one-hot targets so it's a 2D tensor with size $(M*N) \times C$ where $C$ is the number of classes/characters we have. Remember that we reshaped the LSTM outputs and ran them through a fully connected layer with $C$ units. So our logits will also have size $(M*N) \times C$.
#
# Then we run the logits and targets through `tf.nn.softmax_cross_entropy_with_logits` and find the mean to get the loss.

# %%
def build_loss(logits, targets, lstm_size, num_classes):
    ''' Calculate the loss from the logits and the targets.
    
        Arguments
        ---------
        logits: Logits from final fully connected layer
        targets: Targets for supervised learning
        lstm_size: Number of LSTM hidden units
        num_classes: Number of classes in targets
        
    '''
    
    # One-hot encode targets and reshape to match logits, one row per batch_size per step
    y_one_hot = tf.one_hot(targets, num_classes)
    y_reshaped = tf.reshape(y_one_hot, logits.get_shape())
    
    # Softmax cross entropy loss
    loss = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y_reshaped)
    loss = tf.reduce_mean(loss)
    return loss

# %% [markdown]
# ### Optimizer
#
# Here we build the optimizer. Normal RNNs have have issues gradients exploding and disappearing. LSTMs fix the disappearance problem, but the gradients can still grow without bound. To fix this, we can clip the gradients above some threshold. That is, if a gradient is larger than that threshold, we set it to the threshold. This will ensure the gradients never grow overly large. Then we use an AdamOptimizer for the learning step.

# %%
def build_optimizer(loss, learning_rate, grad_clip):
    ''' Build optmizer for training, using gradient clipping.
    
        Arguments:
        loss: Network loss
        learning_rate: Learning rate for optimizer
    
    '''
    
    # Optimizer for training, using gradient clipping to control exploding gradients
    tvars = tf.trainable_variables()
    grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), grad_clip)
    train_op = tf.train.AdamOptimizer(learning_rate)
    optimizer = train_op.apply_gradients(zip(grads, tvars))
    
    return optimizer

# %% [markdown]
# ### Build the network
#
# Now we can put all the pieces together and build a class for the network. To actually run data through the LSTM cells, we will use [`tf.nn.dynamic_rnn`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/nn/dynamic_rnn). This function will pass the hidden and cell states across LSTM cells appropriately for us. It returns the outputs for each LSTM cell at each step for each sequence in the mini-batch. It also gives us the final LSTM state. We want to save this state as `final_state` so we can pass it to the first LSTM cell in the the next mini-batch run. For `tf.nn.dynamic_rnn`, we pass in the cell and initial state we get from `build_lstm`, as well as our input sequences. Also, we need to one-hot encode the inputs before going into the RNN.

# %%
class CharRNN:
    
    def __init__(self, num_classes, batch_size=64, num_steps=50, 
                       lstm_size=128, num_layers=2, learning_rate=0.001, 
                       grad_clip=5, sampling=False):
    
        # When we're using this network for sampling later, we'll be passing in
        # one character at a time, so providing an option for that
        if sampling == True:
            batch_size, num_steps = 1, 1
        else:
            batch_size, num_steps = batch_size, num_steps

        tf.reset_default_graph()
        
        # Build the input placeholder tensors
        self.inputs, self.targets, self.keep_prob = build_inputs(batch_size, num_steps)

        # Build the LSTM cell
        cell, self.initial_state = build_lstm(lstm_size, num_layers, batch_size, self.keep_prob)

        ### Run the data through the RNN layers
        # First, one-hot encode the input tokens
        x_one_hot = tf.one_hot(self.inputs, num_classes)
        
        # Run each sequence step through the RNN and collect the outputs
        outputs, state = tf.nn.dynamic_rnn(cell, x_one_hot, initial_state=self.initial_state)
        self.final_state = state
        
        # Get softmax predictions and logits
        self.prediction, self.logits = build_output(outputs, lstm_size, num_classes)
        
        # Loss and optimizer (with gradient clipping)
        self.loss = build_loss(self.logits, self.targets, lstm_size, num_classes)
        self.optimizer = build_optimizer(self.loss, learning_rate, grad_clip)

# %% [markdown]
# ## Hyperparameters
#
# Here I'm defining the hyperparameters for the network.
#
# * `batch_size` - Number of sequences running through the network in one pass.
# * `num_steps` - Number of characters in the sequence the network is trained on. Larger is better typically, the network will learn more long range dependencies. But it takes longer to train. 100 is typically a good number here.
# * `lstm_size` - The number of units in the hidden layers.
# * `num_layers` - Number of hidden LSTM layers to use
# * `learning_rate` - Learning rate for training
# * `keep_prob` - The dropout keep probability when training. If you're network is overfitting, try decreasing this.
#
# Here's some good advice from Andrej Karpathy on training the network. I'm going to copy it in here for your benefit, but also link to [where it originally came from](https://github.com/karpathy/char-rnn#tips-and-tricks).
#
# > ## Tips and Tricks
#
# >### Monitoring Validation Loss vs. Training Loss
# >If you're somewhat new to Machine Learning or Neural Networks it can take a bit of expertise to get good models. The most important quantity to keep track of is the difference between your training loss (printed during training) and the validation loss (printed once in a while when the RNN is run on the validation data (by default every 1000 iterations)). In particular:
#
# > - If your training loss is much lower than validation loss then this means the network might be **overfitting**. Solutions to this are to decrease your network size, or to increase dropout. For example you could try dropout of 0.5 and so on.
# > - If your training/validation loss are about equal then your model is **underfitting**. Increase the size of your model (either number of layers or the raw number of neurons per layer)
#
# > ### Approximate number of parameters
#
# > The two most important parameters that control the model are `lstm_size` and `num_layers`. I would advise that you always use `num_layers` of either 2/3. The `lstm_size` can be adjusted based on how much data you have. The two important quantities to keep track of here are:
#
# > - The number of parameters in your model. This is printed when you start training.
# > - The size of your dataset. 1MB file is approximately 1 million characters.
#
# >These two should be about the same order of magnitude. It's a little tricky to tell. Here are some examples:
#
# > - I have a 100MB dataset and I'm using the default parameter settings (which currently print 150K parameters). My data size is significantly larger (100 mil >> 0.15 mil), so I expect to heavily underfit. I am thinking I can comfortably afford to make `lstm_size` larger.
# > - I have a 10MB dataset and running a 10 million parameter model. I'm slightly nervous and I'm carefully monitoring my validation loss. If it's larger than my training loss then I may want to try to increase dropout a bit and see if that helps the validation loss.
#
# > ### Best models strategy
#
# >The winning strategy to obtaining very good models (if you have the compute time) is to always err on making the network larger (as large as you're willing to wait for it to compute) and then try different dropout values (between 0,1). Whatever model has the best validation performance (the loss, written in the checkpoint filename, low is good) is the one you should use in the end.
#
# >It is very common in deep learning to run many different models with many different hyperparameter settings, and in the end take whatever checkpoint gave the best validation performance.
#
# >By the way, the size of your training and validation splits are also parameters. Make sure you have a decent amount of data in your validation set or otherwise the validation performance will be noisy and not very informative.

# %%
batch_size = 100        # Sequences per batch
num_steps = 100         # Number of sequence steps per batch
lstm_size = 512         # Size of hidden layers in LSTMs
num_layers = 2          # Number of LSTM layers
learning_rate = 0.001   # Learning rate
keep_prob = 0.5         # Dropout keep probability

# %% [markdown]
# ## Time for training
#
# This is typical training code, passing inputs and targets into the network, then running the optimizer. Here we also get back the final LSTM state for the mini-batch. Then, we pass that state back into the network so the next batch can continue the state from the previous batch. And every so often (set by `save_every_n`) I save a checkpoint.
#
# Here I'm saving checkpoints with the format
#
# `i{iteration number}_l{# hidden layer units}.ckpt`

# %%
epochs = 20
# Save every N iterations
save_every_n = 200

model = CharRNN(len(vocab), batch_size=batch_size, num_steps=num_steps,
                lstm_size=lstm_size, num_layers=num_layers, 
                learning_rate=learning_rate)

saver = tf.train.Saver(max_to_keep=100)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    # Use the line below to load a checkpoint and resume training
    #saver.restore(sess, 'checkpoints/______.ckpt')
    counter = 0
    for e in range(epochs):
        # Train network
        new_state = sess.run(model.initial_state)
        loss = 0
        for x, y in get_batches(encoded, batch_size, num_steps):
            counter += 1
            start = time.time()
            feed = {model.inputs: x,
                    model.targets: y,
                    model.keep_prob: keep_prob,
                    model.initial_state: new_state}
            batch_loss, new_state, _ = sess.run([model.loss, 
                                                 model.final_state, 
                                                 model.optimizer], 
                                                 feed_dict=feed)
            print(batch_loss)
            end = time.time()
            print('Epoch: {}/{}... '.format(e+1, epochs),
                  'Training Step: {}... '.format(counter),
                  'Training loss: {:.4f}... '.format(batch_loss),
                  '{:.4f} sec/batch'.format((end-start)))
        
            if (counter % save_every_n == 0):
                saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
    
    saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
# Out:
# 4.41969
# Epoch: 1/20...  Training Step: 1...  Training loss: 4.4197...  0.6594 sec/batch
# 4.32839
# Epoch: 1/20...  Training Step: 2...  Training loss: 4.3284...  0.4769 sec/batch
# 3.85131
# Epoch: 1/20...  Training Step: 3...  Training loss: 3.8513...  0.4767 sec/batch
# 5.75203
# Epoch: 1/20...  Training Step: 4...  Training loss: 5.7520...  0.4766 sec/batch
# 4.26229
# Epoch: 1/20...  Training Step: 5...  Training loss: 4.2623...  0.4760 sec/batch
# 3.88602
# Epoch: 1/20...  Training Step: 6...  Training loss: 3.8860...  0.4763 sec/batch
# 3.79838
# Epoch: 1/20...  Training Step: 7...  Training loss: 3.7984...  0.4766 sec/batch
# 3.66612
# Epoch: 1/20...  Training Step: 8...  Training loss: 3.6661...  0.4756 sec/batch
# 3.56
# Epoch: 1/20...  Training Step: 9...  Training loss: 3.5600...  0.4763 sec/batch
# 3.46728
# Epoch: 1/20...  Training Step: 10...  Training loss: 3.4673...  0.4772 sec/batch
# 3.39923
# Epoch: 1/20...  Training Step: 11...  Training loss: 3.3992...  0.4766 sec/batch
# 3.38425
# Epoch: 1/20...  Training Step: 12...  Training loss: 3.3843...  0.4764 sec/batch
# 3.3693
# Epoch: 1/20...  Training Step: 13...  Training loss: 3.3693...  0.4758 sec/batch
# 3.36441
# Epoch: 1/20...  Training Step: 14...  Training loss: 3.3644...  0.4760 sec/batch
# 3.34621
# Epoch: 1/20...  Training Step: 15...  Training loss: 3.3462...  0.4757 sec/batch
# 3.32071
# Epoch: 1/20...  Training Step: 16...  Training loss: 3.3207...  0.4765 sec/batch
# 3.31162
# Epoch: 1/20...  Training Step: 17...  Training loss: 3.3116...  0.4755 sec/batch
# 3.32795
# Epoch: 1/20...  Training Step: 18...  Training loss: 3.3279...  0.4757 sec/batch
# 3.30962
# Epoch: 1/20...  Training Step: 19...  Training loss: 3.3096...  0.4761 sec/batch
# 3.25877
# Epoch: 1/20...  Training Step: 20...  Training loss: 3.2588...  0.4762 sec/batch
# 3.27738
# Epoch: 1/20...  Training Step: 21...  Training loss: 3.2774...  0.4760 sec/batch
# 3.26954
# Epoch: 1/20...  Training Step: 22...  Training loss: 3.2695...  0.4766 sec/batch
# 3.26191
# Epoch: 1/20...  Training Step: 23...  Training loss: 3.2619...  0.4768 sec/batch
# 3.25953
# Epoch: 1/20...  Training Step: 24...  Training loss: 3.2595...  0.4765 sec/batch
# 3.23585
# Epoch: 1/20...  Training Step: 25...  Training loss: 3.2358...  0.4776 sec/batch
# 3.25263
# Epoch: 1/20...  Training Step: 26...  Training loss: 3.2526...  0.4768 sec/batch
# 3.24489
# Epoch: 1/20...  Training Step: 27...  Training loss: 3.2449...  0.4773 sec/batch
# 3.22212
# Epoch: 1/20...  Training Step: 28...  Training loss: 3.2221...  0.4758 sec/batch
# 3.22141
# Epoch: 1/20...  Training Step: 29...  Training loss: 3.2214...  0.4775 sec/batch
# 3.22894
# Epoch: 1/20...  Training Step: 30...  Training loss: 3.2289...  0.4766 sec/batch
# 3.25348
# Epoch: 1/20...  Training Step: 31...  Training loss: 3.2535...  0.4766 sec/batch
# 3.2174
# Epoch: 1/20...  Training Step: 32...  Training loss: 3.2174...  0.4758 sec/batch
# 3.2025
# Epoch: 1/20...  Training Step: 33...  Training loss: 3.2025...  0.4765 sec/batch
# 3.2188
# Epoch: 1/20...  Training Step: 34...  Training loss: 3.2188...  0.4769 sec/batch
# 3.19945
# Epoch: 1/20...  Training Step: 35...  Training loss: 3.1994...  0.4769 sec/batch
# 3.22059
# Epoch: 1/20...  Training Step: 36...  Training loss: 3.2206...  0.4765 sec/batch
# 3.18057
# Epoch: 1/20...  Training Step: 37...  Training loss: 3.1806...  0.4759 sec/batch
# 3.18999
# Epoch: 1/20...  Training Step: 38...  Training loss: 3.1900...  0.4763 sec/batch
# 3.17827
# Epoch: 1/20...  Training Step: 39...  Training loss: 3.1783...  0.4767 sec/batch
# 3.18109
# Epoch: 1/20...  Training Step: 40...  Training loss: 3.1811...  0.4769 sec/batch
# 3.16949
# Epoch: 1/20...  Training Step: 41...  Training loss: 3.1695...  0.4765 sec/batch
# 3.18031
# Epoch: 1/20...  Training Step: 42...  Training loss: 3.1803...  0.4769 sec/batch
# 3.1682
# Epoch: 1/20...  Training Step: 43...  Training loss: 3.1682...  0.4764 sec/batch
# 3.17245
# Epoch: 1/20...  Training Step: 44...  Training loss: 3.1724...  0.4760 sec/batch
# 3.16456
# Epoch: 1/20...  Training Step: 45...  Training loss: 3.1646...  0.4763 sec/batch
# 3.17194
# Epoch: 1/20...  Training Step: 46...  Training loss: 3.1719...  0.4772 sec/batch
# 3.1798
# Epoch: 1/20...  Training Step: 47...  Training loss: 3.1798...  0.4761 sec/batch
# 3.17533
# Epoch: 1/20...  Training Step: 48...  Training loss: 3.1753...  0.4755 sec/batch
# 3.18038
# Epoch: 1/20...  Training Step: 49...  Training loss: 3.1804...  0.4769 sec/batch
# 3.17372
# Epoch: 1/20...  Training Step: 50...  Training loss: 3.1737...  0.4755 sec/batch
# 3.1616
# Epoch: 1/20...  Training Step: 51...  Training loss: 3.1616...  0.4759 sec/batch
# 3.15452
# Epoch: 1/20...  Training Step: 52...  Training loss: 3.1545...  0.4760 sec/batch
# 3.1657
# Epoch: 1/20...  Training Step: 53...  Training loss: 3.1657...  0.4767 sec/batch
# 3.14557
# Epoch: 1/20...  Training Step: 54...  Training loss: 3.1456...  0.4756 sec/batch
# 3.15925
# Epoch: 1/20...  Training Step: 55...  Training loss: 3.1592...  0.4751 sec/batch
# 3.13919
# Epoch: 1/20...  Training Step: 56...  Training loss: 3.1392...  0.4762 sec/batch
# 3.15228
# Epoch: 1/20...  Training Step: 57...  Training loss: 3.1523...  0.4757 sec/batch
# 3.15384
# Epoch: 1/20...  Training Step: 58...  Training loss: 3.1538...  0.4763 sec/batch
# 3.13585
# Epoch: 1/20...  Training Step: 59...  Training loss: 3.1358...  0.4762 sec/batch
# 3.15081
# Epoch: 1/20...  Training Step: 60...  Training loss: 3.1508...  0.4765 sec/batch
# 3.15273
# Epoch: 1/20...  Training Step: 61...  Training loss: 3.1527...  0.4761 sec/batch
# 3.1678
# Epoch: 1/20...  Training Step: 62...  Training loss: 3.1678...  0.4764 sec/batch
# 3.16818
# Epoch: 1/20...  Training Step: 63...  Training loss: 3.1682...  0.4770 sec/batch
# 3.12525
# Epoch: 1/20...  Training Step: 64...  Training loss: 3.1253...  0.4763 sec/batch
# 3.12549
# Epoch: 1/20...  Training Step: 65...  Training loss: 3.1255...  0.4764 sec/batch
# 3.16221
# Epoch: 1/20...  Training Step: 66...  Training loss: 3.1622...  0.4758 sec/batch
# 3.15215
# Epoch: 1/20...  Training Step: 67...  Training loss: 3.1521...  0.4761 sec/batch
# 3.1053
# Epoch: 1/20...  Training Step: 68...  Training loss: 3.1053...  0.4765 sec/batch
# 3.12742
# Epoch: 1/20...  Training Step: 69...  Training loss: 3.1274...  0.4759 sec/batch
# 3.151
# Epoch: 1/20...  Training Step: 70...  Training loss: 3.1510...  0.4761 sec/batch
# 3.13633
# Epoch: 1/20...  Training Step: 71...  Training loss: 3.1363...  0.4771 sec/batch
# 3.15792
# Epoch: 1/20...  Training Step: 72...  Training loss: 3.1579...  0.4759 sec/batch
# 3.13268
# Epoch: 1/20...  Training Step: 73...  Training loss: 3.1327...  0.4759 sec/batch
# 3.13884
# Epoch: 1/20...  Training Step: 74...  Training loss: 3.1388...  0.4767 sec/batch
# 3.14717
# Epoch: 1/20...  Training Step: 75...  Training loss: 3.1472...  0.4760 sec/batch
# 3.1472
# Epoch: 1/20...  Training Step: 76...  Training loss: 3.1472...  0.4757 sec/batch
# 3.13999
# Epoch: 1/20...  Training Step: 77...  Training loss: 3.1400...  0.4758 sec/batch
# 3.13408
# Epoch: 1/20...  Training Step: 78...  Training loss: 3.1341...  0.4758 sec/batch
# 3.12845
# Epoch: 1/20...  Training Step: 79...  Training loss: 3.1284...  0.4762 sec/batch
# 3.11539
# Epoch: 1/20...  Training Step: 80...  Training loss: 3.1154...  0.4763 sec/batch
# 3.1127
# Epoch: 1/20...  Training Step: 81...  Training loss: 3.1127...  0.4761 sec/batch
# 3.13938
# Epoch: 1/20...  Training Step: 82...  Training loss: 3.1394...  0.4771 sec/batch
# 3.13164
# Epoch: 1/20...  Training Step: 83...  Training loss: 3.1316...  0.4757 sec/batch
# 3.12338
# Epoch: 1/20...  Training Step: 84...  Training loss: 3.1234...  0.4762 sec/batch
# 3.11245
# Epoch: 1/20...  Training Step: 85...  Training loss: 3.1125...  0.4758 sec/batch
# 3.11097
# Epoch: 1/20...  Training Step: 86...  Training loss: 3.1110...  0.4762 sec/batch
# 3.10653
# Epoch: 1/20...  Training Step: 87...  Training loss: 3.1065...  0.4755 sec/batch
# 3.11023
# Epoch: 1/20...  Training Step: 88...  Training loss: 3.1102...  0.4752 sec/batch
# 3.12813
# Epoch: 1/20...  Training Step: 89...  Training loss: 3.1281...  0.4754 sec/batch
# 3.12032
# Epoch: 1/20...  Training Step: 90...  Training loss: 3.1203...  0.4748 sec/batch
# 3.11632
# Epoch: 1/20...  Training Step: 91...  Training loss: 3.1163...  0.4758 sec/batch
# 3.10326
# Epoch: 1/20...  Training Step: 92...  Training loss: 3.1033...  0.4758 sec/batch
# 3.11327
# Epoch: 1/20...  Training Step: 93...  Training loss: 3.1133...  0.4763 sec/batch
# 3.11586
# Epoch: 1/20...  Training Step: 94...  Training loss: 3.1159...  0.4762 sec/batch
# 3.09872
# Epoch: 1/20...  Training Step: 95...  Training loss: 3.0987...  0.4763 sec/batch
# 3.09645
# Epoch: 1/20...  Training Step: 96...  Training loss: 3.0964...  0.4763 sec/batch
# 3.10731
# Epoch: 1/20...  Training Step: 97...  Training loss: 3.1073...  0.4760 sec/batch
# 3.09354
# Epoch: 1/20...  Training Step: 98...  Training loss: 3.0935...  0.4761 sec/batch
# 3.0976
# Epoch: 1/20...  Training Step: 99...  Training loss: 3.0976...  0.4760 sec/batch
# 3.08905
# Epoch: 1/20...  Training Step: 100...  Training loss: 3.0890...  0.4764 sec/batch
# 3.09348
# Epoch: 1/20...  Training Step: 101...  Training loss: 3.0935...  0.4755 sec/batch
# 3.09348
# Epoch: 1/20...  Training Step: 102...  Training loss: 3.0935...  0.4757 sec/batch
# 3.08999
# Epoch: 1/20...  Training Step: 103...  Training loss: 3.0900...  0.4755 sec/batch
# 3.07932
# Epoch: 1/20...  Training Step: 104...  Training loss: 3.0793...  0.4752 sec/batch
# 3.08065
# Epoch: 1/20...  Training Step: 105...  Training loss: 3.0806...  0.4760 sec/batch
# 3.07917
# Epoch: 1/20...  Training Step: 106...  Training loss: 3.0792...  0.4759 sec/batch
# 3.04925
# Epoch: 1/20...  Training Step: 107...  Training loss: 3.0492...  0.4768 sec/batch
# 3.0588
# Epoch: 1/20...  Training Step: 108...  Training loss: 3.0588...  0.4769 sec/batch
# 3.07994
# Epoch: 1/20...  Training Step: 109...  Training loss: 3.0799...  0.4765 sec/batch
# 3.05265
# Epoch: 1/20...  Training Step: 110...  Training loss: 3.0526...  0.4773 sec/batch
# 3.06943
# Epoch: 1/20...  Training Step: 111...  Training loss: 3.0694...  0.4757 sec/batch
# 3.06928
# Epoch: 1/20...  Training Step: 112...  Training loss: 3.0693...  0.4754 sec/batch
# 3.0451
# Epoch: 1/20...  Training Step: 113...  Training loss: 3.0451...  0.4767 sec/batch
# 3.04645
# Epoch: 1/20...  Training Step: 114...  Training loss: 3.0465...  0.4764 sec/batch
# 3.03293
# Epoch: 1/20...  Training Step: 115...  Training loss: 3.0329...  0.4777 sec/batch
# 3.03645
# Epoch: 1/20...  Training Step: 116...  Training loss: 3.0365...  0.4768 sec/batch
# 3.03136
# Epoch: 1/20...  Training Step: 117...  Training loss: 3.0314...  0.4757 sec/batch
# 3.04974
# Epoch: 1/20...  Training Step: 118...  Training loss: 3.0497...  0.4758 sec/batch
# 3.03687
# Epoch: 1/20...  Training Step: 119...  Training loss: 3.0369...  0.4749 sec/batch
# 3.00385
# Epoch: 1/20...  Training Step: 120...  Training loss: 3.0038...  0.4760 sec/batch
# 3.05328
# Epoch: 1/20...  Training Step: 121...  Training loss: 3.0533...  0.4756 sec/batch
# 3.03764
# Epoch: 1/20...  Training Step: 122...  Training loss: 3.0376...  0.4760 sec/batch
# 3.01044
# Epoch: 1/20...  Training Step: 123...  Training loss: 3.0104...  0.4763 sec/batch
# 3.02567
# Epoch: 1/20...  Training Step: 124...  Training loss: 3.0257...  0.4752 sec/batch
# 3.00084
# Epoch: 1/20...  Training Step: 125...  Training loss: 3.0008...  0.4758 sec/batch
# 2.9728
# Epoch: 1/20...  Training Step: 126...  Training loss: 2.9728...  0.4762 sec/batch
# 2.99145
# Epoch: 1/20...  Training Step: 127...  Training loss: 2.9915...  0.4765 sec/batch
# 2.99686
# Epoch: 1/20...  Training Step: 128...  Training loss: 2.9969...  0.4760 sec/batch
# 2.97146
# Epoch: 1/20...  Training Step: 129...  Training loss: 2.9715...  0.4762 sec/batch
# 2.96971
# Epoch: 1/20...  Training Step: 130...  Training loss: 2.9697...  0.4764 sec/batch
# 2.96207
# Epoch: 1/20...  Training Step: 131...  Training loss: 2.9621...  0.4760 sec/batch
# 2.94691
# Epoch: 1/20...  Training Step: 132...  Training loss: 2.9469...  0.4757 sec/batch
# 2.95726
# Epoch: 1/20...  Training Step: 133...  Training loss: 2.9573...  0.4756 sec/batch
# 2.9429
# Epoch: 1/20...  Training Step: 134...  Training loss: 2.9429...  0.4762 sec/batch
# 2.90336
# Epoch: 1/20...  Training Step: 135...  Training loss: 2.9034...  0.4762 sec/batch
# 2.9156
# Epoch: 1/20...  Training Step: 136...  Training loss: 2.9156...  0.4757 sec/batch
# 2.90932
# Epoch: 1/20...  Training Step: 137...  Training loss: 2.9093...  0.4762 sec/batch
# 2.89647
# Epoch: 1/20...  Training Step: 138...  Training loss: 2.8965...  0.4757 sec/batch
# 2.90195
# Epoch: 1/20...  Training Step: 139...  Training loss: 2.9019...  0.4765 sec/batch
# 2.89147
# Epoch: 1/20...  Training Step: 140...  Training loss: 2.8915...  0.4759 sec/batch
# 2.88493
# Epoch: 1/20...  Training Step: 141...  Training loss: 2.8849...  0.4761 sec/batch
# 2.84507
# Epoch: 1/20...  Training Step: 142...  Training loss: 2.8451...  0.4765 sec/batch
# 2.84225
# Epoch: 1/20...  Training Step: 143...  Training loss: 2.8423...  0.4763 sec/batch
# 2.83269
# Epoch: 1/20...  Training Step: 144...  Training loss: 2.8327...  0.4759 sec/batch
# 2.8442
# Epoch: 1/20...  Training Step: 145...  Training loss: 2.8442...  0.4764 sec/batch
# 2.84196
# Epoch: 1/20...  Training Step: 146...  Training loss: 2.8420...  0.4774 sec/batch
# 2.82284
# Epoch: 1/20...  Training Step: 147...  Training loss: 2.8228...  0.4769 sec/batch
# 2.83643
# Epoch: 1/20...  Training Step: 148...  Training loss: 2.8364...  0.4767 sec/batch
# 2.77635
# Epoch: 1/20...  Training Step: 149...  Training loss: 2.7764...  0.4773 sec/batch
# 2.78629
# Epoch: 1/20...  Training Step: 150...  Training loss: 2.7863...  0.4775 sec/batch
# 2.80655
# Epoch: 1/20...  Training Step: 151...  Training loss: 2.8066...  0.4779 sec/batch
# 2.80931
# Epoch: 1/20...  Training Step: 152...  Training loss: 2.8093...  0.4761 sec/batch
# 2.8012
# Epoch: 1/20...  Training Step: 153...  Training loss: 2.8012...  0.4760 sec/batch
# 2.80672
# Epoch: 1/20...  Training Step: 154...  Training loss: 2.8067...  0.4764 sec/batch
# 2.75309
# Epoch: 1/20...  Training Step: 155...  Training loss: 2.7531...  0.4760 sec/batch
# 2.75535
# Epoch: 1/20...  Training Step: 156...  Training loss: 2.7554...  0.4767 sec/batch
# 2.72533
# Epoch: 1/20...  Training Step: 157...  Training loss: 2.7253...  0.4765 sec/batch
# 2.72593
# Epoch: 1/20...  Training Step: 158...  Training loss: 2.7259...  0.4766 sec/batch
# 2.70511
# Epoch: 1/20...  Training Step: 159...  Training loss: 2.7051...  0.4772 sec/batch
# 2.72545
# Epoch: 1/20...  Training Step: 160...  Training loss: 2.7255...  0.4763 sec/batch
# 2.71689
# Epoch: 1/20...  Training Step: 161...  Training loss: 2.7169...  0.4763 sec/batch
# 2.66619
# Epoch: 1/20...  Training Step: 162...  Training loss: 2.6662...  0.4769 sec/batch
# 2.65679
# Epoch: 1/20...  Training Step: 163...  Training loss: 2.6568...  0.4764 sec/batch
# 2.672
# Epoch: 1/20...  Training Step: 164...  Training loss: 2.6720...  0.4757 sec/batch
# 2.67604
# Epoch: 1/20...  Training Step: 165...  Training loss: 2.6760...  0.4762 sec/batch
# 2.6569
# Epoch: 1/20...  Training Step: 166...  Training loss: 2.6569...  0.4757 sec/batch
# 2.65661
# Epoch: 1/20...  Training Step: 167...  Training loss: 2.6566...  0.4764 sec/batch
# 2.64347
# Epoch: 1/20...  Training Step: 168...  Training loss: 2.6435...  0.4764 sec/batch
# 2.63991
# Epoch: 1/20...  Training Step: 169...  Training loss: 2.6399...  0.4758 sec/batch
# 2.61009
# Epoch: 1/20...  Training Step: 170...  Training loss: 2.6101...  0.4766 sec/batch
# 2.62513
# Epoch: 1/20...  Training Step: 171...  Training loss: 2.6251...  0.4760 sec/batch
# 2.6435
# Epoch: 1/20...  Training Step: 172...  Training loss: 2.6435...  0.4771 sec/batch
# 2.68828
# Epoch: 1/20...  Training Step: 173...  Training loss: 2.6883...  0.4757 sec/batch
# 2.65528
# Epoch: 1/20...  Training Step: 174...  Training loss: 2.6553...  0.4763 sec/batch
# 2.61594
# Epoch: 1/20...  Training Step: 175...  Training loss: 2.6159...  0.4773 sec/batch
# 2.59779
# Epoch: 1/20...  Training Step: 176...  Training loss: 2.5978...  0.4770 sec/batch
# 2.58698
# Epoch: 1/20...  Training Step: 177...  Training loss: 2.5870...  0.4761 sec/batch
# 2.56577
# Epoch: 1/20...  Training Step: 178...  Training loss: 2.5658...  0.4764 sec/batch
# 2.55751
# Epoch: 1/20...  Training Step: 179...  Training loss: 2.5575...  0.4767 sec/batch
# 2.54456
# Epoch: 1/20...  Training Step: 180...  Training loss: 2.5446...  0.4766 sec/batch
# 2.55897
# Epoch: 1/20...  Training Step: 181...  Training loss: 2.5590...  0.4764 sec/batch
# 2.56084
# Epoch: 1/20...  Training Step: 182...  Training loss: 2.5608...  0.4758 sec/batch
# 2.54648
# Epoch: 1/20...  Training Step: 183...  Training loss: 2.5465...  0.4762 sec/batch
# 2.58455
# Epoch: 1/20...  Training Step: 184...  Training loss: 2.5845...  0.4761 sec/batch
# 2.60695
# Epoch: 1/20...  Training Step: 185...  Training loss: 2.6070...  0.4761 sec/batch
# 2.55024
# Epoch: 1/20...  Training Step: 186...  Training loss: 2.5502...  0.4767 sec/batch
# 2.52084
# Epoch: 1/20...  Training Step: 187...  Training loss: 2.5208...  0.4752 sec/batch
# 2.51496
# Epoch: 1/20...  Training Step: 188...  Training loss: 2.5150...  0.4763 sec/batch
# 2.51911
# Epoch: 1/20...  Training Step: 189...  Training loss: 2.5191...  0.4765 sec/batch
# 2.5199
# Epoch: 1/20...  Training Step: 190...  Training loss: 2.5199...  0.4763 sec/batch
# 2.52265
# Epoch: 1/20...  Training Step: 191...  Training loss: 2.5226...  0.4761 sec/batch
# 2.4856
# Epoch: 1/20...  Training Step: 192...  Training loss: 2.4856...  0.4763 sec/batch
# 2.51006
# Epoch: 1/20...  Training Step: 193...  Training loss: 2.5101...  0.4787 sec/batch
# 2.50278
# Epoch: 1/20...  Training Step: 194...  Training loss: 2.5028...  0.4764 sec/batch
# 2.49509
# Epoch: 1/20...  Training Step: 195...  Training loss: 2.4951...  0.4757 sec/batch
# 2.4901
# Epoch: 1/20...  Training Step: 196...  Training loss: 2.4901...  0.4760 sec/batch
# 2.48041
# Epoch: 1/20...  Training Step: 197...  Training loss: 2.4804...  0.4770 sec/batch
# 2.48264
# Epoch: 1/20...  Training Step: 198...  Training loss: 2.4826...  0.4766 sec/batch
# 2.55722
# Epoch: 2/20...  Training Step: 199...  Training loss: 2.5572...  0.4758 sec/batch
# 2.45086
# Epoch: 2/20...  Training Step: 200...  Training loss: 2.4509...  0.4762 sec/batch
# 2.47099
# Epoch: 2/20...  Training Step: 201...  Training loss: 2.4710...  0.4764 sec/batch
# 2.47628
# Epoch: 2/20...  Training Step: 202...  Training loss: 2.4763...  0.4761 sec/batch
# 2.47839
# Epoch: 2/20...  Training Step: 203...  Training loss: 2.4784...  0.4768 sec/batch
# 2.46735
# Epoch: 2/20...  Training Step: 204...  Training loss: 2.4674...  0.4760 sec/batch
# 2.47108
# Epoch: 2/20...  Training Step: 205...  Training loss: 2.4711...  0.4762 sec/batch
# 2.47546
# Epoch: 2/20...  Training Step: 206...  Training loss: 2.4755...  0.4763 sec/batch
# 2.48387
# Epoch: 2/20...  Training Step: 207...  Training loss: 2.4839...  0.4759 sec/batch
# 2.45467
# Epoch: 2/20...  Training Step: 208...  Training loss: 2.4547...  0.4767 sec/batch
# 2.45056
# Epoch: 2/20...  Training Step: 209...  Training loss: 2.4506...  0.4765 sec/batch
# 2.45873
# Epoch: 2/20...  Training Step: 210...  Training loss: 2.4587...  0.4761 sec/batch
# 2.4569
# Epoch: 2/20...  Training Step: 211...  Training loss: 2.4569...  0.4762 sec/batch
# 2.501
# Epoch: 2/20...  Training Step: 212...  Training loss: 2.5010...  0.4766 sec/batch
# 2.45961
# Epoch: 2/20...  Training Step: 213...  Training loss: 2.4596...  0.4766 sec/batch
# 2.45944
# Epoch: 2/20...  Training Step: 214...  Training loss: 2.4594...  0.4760 sec/batch
# 2.45197
# Epoch: 2/20...  Training Step: 215...  Training loss: 2.4520...  0.4761 sec/batch
# 2.48132
# Epoch: 2/20...  Training Step: 216...  Training loss: 2.4813...  0.4772 sec/batch
# 2.45281
# Epoch: 2/20...  Training Step: 217...  Training loss: 2.4528...  0.4760 sec/batch
# 2.41982
# Epoch: 2/20...  Training Step: 218...  Training loss: 2.4198...  0.4764 sec/batch
# 2.4363
# Epoch: 2/20...  Training Step: 219...  Training loss: 2.4363...  0.4772 sec/batch
# 2.46276
# Epoch: 2/20...  Training Step: 220...  Training loss: 2.4628...  0.4771 sec/batch
# 2.44163
# Epoch: 2/20...  Training Step: 221...  Training loss: 2.4416...  0.4760 sec/batch
# 2.42779
# Epoch: 2/20...  Training Step: 222...  Training loss: 2.4278...  0.4762 sec/batch
# 2.40918
# Epoch: 2/20...  Training Step: 223...  Training loss: 2.4092...  0.4760 sec/batch
# 2.42161
# Epoch: 2/20...  Training Step: 224...  Training loss: 2.4216...  0.4759 sec/batch
# 2.4139
# Epoch: 2/20...  Training Step: 225...  Training loss: 2.4139...  0.4780 sec/batch
# 2.42092
# Epoch: 2/20...  Training Step: 226...  Training loss: 2.4209...  0.4762 sec/batch
# 2.42874
# Epoch: 2/20...  Training Step: 227...  Training loss: 2.4287...  0.4758 sec/batch
# 2.41826
# Epoch: 2/20...  Training Step: 228...  Training loss: 2.4183...  0.4766 sec/batch
# 2.43255
# Epoch: 2/20...  Training Step: 229...  Training loss: 2.4325...  0.4764 sec/batch
# 2.39327
# Epoch: 2/20...  Training Step: 230...  Training loss: 2.3933...  0.4759 sec/batch
# 2.38933
# Epoch: 2/20...  Training Step: 231...  Training loss: 2.3893...  0.4759 sec/batch
# 2.41573
# Epoch: 2/20...  Training Step: 232...  Training loss: 2.4157...  0.4765 sec/batch
# 2.38737
# Epoch: 2/20...  Training Step: 233...  Training loss: 2.3874...  0.4765 sec/batch
# 2.40772
# Epoch: 2/20...  Training Step: 234...  Training loss: 2.4077...  0.4762 sec/batch
# 2.38337
# Epoch: 2/20...  Training Step: 235...  Training loss: 2.3834...  0.4759 sec/batch
# 2.35747
# Epoch: 2/20...  Training Step: 236...  Training loss: 2.3575...  0.4758 sec/batch
# 2.37229
# Epoch: 2/20...  Training Step: 237...  Training loss: 2.3723...  0.4763 sec/batch
# 2.36286
# Epoch: 2/20...  Training Step: 238...  Training loss: 2.3629...  0.4758 sec/batch
# 2.3622
# Epoch: 2/20...  Training Step: 239...  Training loss: 2.3622...  0.4758 sec/batch
# 2.35989
# Epoch: 2/20...  Training Step: 240...  Training loss: 2.3599...  0.4763 sec/batch
# 2.35704
# Epoch: 2/20...  Training Step: 241...  Training loss: 2.3570...  0.4761 sec/batch
# 2.35143
# Epoch: 2/20...  Training Step: 242...  Training loss: 2.3514...  0.4765 sec/batch
# 2.3566
# Epoch: 2/20...  Training Step: 243...  Training loss: 2.3566...  0.4758 sec/batch
# 2.32327
# Epoch: 2/20...  Training Step: 244...  Training loss: 2.3233...  0.4762 sec/batch
# 2.37989
# Epoch: 2/20...  Training Step: 245...  Training loss: 2.3799...  0.4763 sec/batch
# 2.34769
# Epoch: 2/20...  Training Step: 246...  Training loss: 2.3477...  0.4762 sec/batch
# 2.35796
# Epoch: 2/20...  Training Step: 247...  Training loss: 2.3580...  0.4761 sec/batch
# 2.37893
# Epoch: 2/20...  Training Step: 248...  Training loss: 2.3789...  0.4758 sec/batch
# 2.33219
# Epoch: 2/20...  Training Step: 249...  Training loss: 2.3322...  0.4756 sec/batch
# 2.37198
# Epoch: 2/20...  Training Step: 250...  Training loss: 2.3720...  0.4753 sec/batch
# 2.34135
# Epoch: 2/20...  Training Step: 251...  Training loss: 2.3413...  0.4771 sec/batch
# 2.33258
# Epoch: 2/20...  Training Step: 252...  Training loss: 2.3326...  0.4758 sec/batch
# 2.32784
# Epoch: 2/20...  Training Step: 253...  Training loss: 2.3278...  0.4758 sec/batch
# 2.35077
# Epoch: 2/20...  Training Step: 254...  Training loss: 2.3508...  0.4764 sec/batch
# 2.34171
# Epoch: 2/20...  Training Step: 255...  Training loss: 2.3417...  0.4762 sec/batch
# 2.33018
# Epoch: 2/20...  Training Step: 256...  Training loss: 2.3302...  0.4764 sec/batch
# 2.32753
# Epoch: 2/20...  Training Step: 257...  Training loss: 2.3275...  0.4765 sec/batch
# 2.35705
# Epoch: 2/20...  Training Step: 258...  Training loss: 2.3571...  0.4760 sec/batch
# 2.32381
# Epoch: 2/20...  Training Step: 259...  Training loss: 2.3238...  0.4762 sec/batch
# 2.34785
# Epoch: 2/20...  Training Step: 260...  Training loss: 2.3479...  0.4766 sec/batch
# 2.34861
# Epoch: 2/20...  Training Step: 261...  Training loss: 2.3486...  0.4768 sec/batch
# 2.31388
# Epoch: 2/20...  Training Step: 262...  Training loss: 2.3139...  0.4762 sec/batch
# 2.31315
# Epoch: 2/20...  Training Step: 263...  Training loss: 2.3131...  0.4762 sec/batch
# 2.33994
# Epoch: 2/20...  Training Step: 264...  Training loss: 2.3399...  0.4760 sec/batch
# 2.31755
# Epoch: 2/20...  Training Step: 265...  Training loss: 2.3175...  0.4765 sec/batch
# 2.29514
# Epoch: 2/20...  Training Step: 266...  Training loss: 2.2951...  0.4761 sec/batch
# 2.28631
# Epoch: 2/20...  Training Step: 267...  Training loss: 2.2863...  0.4765 sec/batch
# 2.31542
# Epoch: 2/20...  Training Step: 268...  Training loss: 2.3154...  0.4765 sec/batch
# 2.33207
# Epoch: 2/20...  Training Step: 269...  Training loss: 2.3321...  0.4767 sec/batch
# 2.31389
# Epoch: 2/20...  Training Step: 270...  Training loss: 2.3139...  0.4763 sec/batch
# 2.31279
# Epoch: 2/20...  Training Step: 271...  Training loss: 2.3128...  0.4768 sec/batch
# 2.3
# Epoch: 2/20...  Training Step: 272...  Training loss: 2.3000...  0.4767 sec/batch
# 2.29472
# Epoch: 2/20...  Training Step: 273...  Training loss: 2.2947...  0.4769 sec/batch
# 2.34196
# Epoch: 2/20...  Training Step: 274...  Training loss: 2.3420...  0.4769 sec/batch
# 2.30672
# Epoch: 2/20...  Training Step: 275...  Training loss: 2.3067...  0.4758 sec/batch
# 2.305
# Epoch: 2/20...  Training Step: 276...  Training loss: 2.3050...  0.4765 sec/batch
# 2.27962
# Epoch: 2/20...  Training Step: 277...  Training loss: 2.2796...  0.4767 sec/batch
# 2.28875
# Epoch: 2/20...  Training Step: 278...  Training loss: 2.2887...  0.4762 sec/batch
# 2.2677
# Epoch: 2/20...  Training Step: 279...  Training loss: 2.2677...  0.4765 sec/batch
# 2.3065
# Epoch: 2/20...  Training Step: 280...  Training loss: 2.3065...  0.4761 sec/batch
# 2.2673
# Epoch: 2/20...  Training Step: 281...  Training loss: 2.2673...  0.4758 sec/batch
# 2.26241
# Epoch: 2/20...  Training Step: 282...  Training loss: 2.2624...  0.4768 sec/batch
# 2.23462
# Epoch: 2/20...  Training Step: 283...  Training loss: 2.2346...  0.4760 sec/batch
# 2.26622
# Epoch: 2/20...  Training Step: 284...  Training loss: 2.2662...  0.4765 sec/batch
# 2.28126
# Epoch: 2/20...  Training Step: 285...  Training loss: 2.2813...  0.4762 sec/batch
# 2.27089
# Epoch: 2/20...  Training Step: 286...  Training loss: 2.2709...  0.4759 sec/batch
# 2.25402
# Epoch: 2/20...  Training Step: 287...  Training loss: 2.2540...  0.4764 sec/batch
# 2.27682
# Epoch: 2/20...  Training Step: 288...  Training loss: 2.2768...  0.4769 sec/batch
# 2.25405
# Epoch: 2/20...  Training Step: 289...  Training loss: 2.2540...  0.4764 sec/batch
# 2.265
# Epoch: 2/20...  Training Step: 290...  Training loss: 2.2650...  0.4778 sec/batch
# 2.24729
# Epoch: 2/20...  Training Step: 291...  Training loss: 2.2473...  0.4765 sec/batch
# 2.24524
# Epoch: 2/20...  Training Step: 292...  Training loss: 2.2452...  0.4774 sec/batch
# 2.24601
# Epoch: 2/20...  Training Step: 293...  Training loss: 2.2460...  0.4761 sec/batch
# 2.2356
# Epoch: 2/20...  Training Step: 294...  Training loss: 2.2356...  0.4764 sec/batch
# 2.25085
# Epoch: 2/20...  Training Step: 295...  Training loss: 2.2508...  0.4766 sec/batch
# 2.24267
# Epoch: 2/20...  Training Step: 296...  Training loss: 2.2427...  0.4761 sec/batch
# 2.23346
# Epoch: 2/20...  Training Step: 297...  Training loss: 2.2335...  0.4768 sec/batch
# 2.22051
# Epoch: 2/20...  Training Step: 298...  Training loss: 2.2205...  0.4762 sec/batch
# 2.2646
# Epoch: 2/20...  Training Step: 299...  Training loss: 2.2646...  0.4760 sec/batch
# 2.24315
# Epoch: 2/20...  Training Step: 300...  Training loss: 2.2431...  0.4765 sec/batch
# 2.21229
# Epoch: 2/20...  Training Step: 301...  Training loss: 2.2123...  0.4760 sec/batch
# 2.22164
# Epoch: 2/20...  Training Step: 302...  Training loss: 2.2216...  0.4759 sec/batch
# 2.22505
# Epoch: 2/20...  Training Step: 303...  Training loss: 2.2251...  0.4761 sec/batch
# 2.23051
# Epoch: 2/20...  Training Step: 304...  Training loss: 2.2305...  0.4761 sec/batch
# 2.22977
# Epoch: 2/20...  Training Step: 305...  Training loss: 2.2298...  0.4756 sec/batch
# 2.24978
# Epoch: 2/20...  Training Step: 306...  Training loss: 2.2498...  0.4767 sec/batch
# 2.24168
# Epoch: 2/20...  Training Step: 307...  Training loss: 2.2417...  0.4760 sec/batch
# 2.21742
# Epoch: 2/20...  Training Step: 308...  Training loss: 2.2174...  0.4762 sec/batch
# 2.22032
# Epoch: 2/20...  Training Step: 309...  Training loss: 2.2203...  0.4759 sec/batch
# 2.24092
# Epoch: 2/20...  Training Step: 310...  Training loss: 2.2409...  0.4775 sec/batch
# 2.22309
# Epoch: 2/20...  Training Step: 311...  Training loss: 2.2231...  0.4761 sec/batch
# 2.20131
# Epoch: 2/20...  Training Step: 312...  Training loss: 2.2013...  0.4761 sec/batch
# 2.20895
# Epoch: 2/20...  Training Step: 313...  Training loss: 2.2090...  0.4761 sec/batch
# 2.17485
# Epoch: 2/20...  Training Step: 314...  Training loss: 2.1749...  0.4762 sec/batch
# 2.22382
# Epoch: 2/20...  Training Step: 315...  Training loss: 2.2238...  0.4760 sec/batch
# 2.19833
# Epoch: 2/20...  Training Step: 316...  Training loss: 2.1983...  0.4756 sec/batch
# 2.24072
# Epoch: 2/20...  Training Step: 317...  Training loss: 2.2407...  0.4763 sec/batch
# 2.21648
# Epoch: 2/20...  Training Step: 318...  Training loss: 2.2165...  0.4765 sec/batch
# 2.23512
# Epoch: 2/20...  Training Step: 319...  Training loss: 2.2351...  0.4760 sec/batch
# 2.20422
# Epoch: 2/20...  Training Step: 320...  Training loss: 2.2042...  0.4764 sec/batch
# 2.19394
# Epoch: 2/20...  Training Step: 321...  Training loss: 2.1939...  0.4772 sec/batch
# 2.23963
# Epoch: 2/20...  Training Step: 322...  Training loss: 2.2396...  0.4764 sec/batch
# 2.19734
# Epoch: 2/20...  Training Step: 323...  Training loss: 2.1973...  0.4770 sec/batch
# 2.17668
# Epoch: 2/20...  Training Step: 324...  Training loss: 2.1767...  0.4770 sec/batch
# 2.21325
# Epoch: 2/20...  Training Step: 325...  Training loss: 2.2133...  0.4762 sec/batch
# 2.21281
# Epoch: 2/20...  Training Step: 326...  Training loss: 2.2128...  0.4761 sec/batch
# 2.20173
# Epoch: 2/20...  Training Step: 327...  Training loss: 2.2017...  0.4765 sec/batch
# 2.20834
# Epoch: 2/20...  Training Step: 328...  Training loss: 2.2083...  0.4764 sec/batch
# 2.17421
# Epoch: 2/20...  Training Step: 329...  Training loss: 2.1742...  0.4765 sec/batch
# 2.17524
# Epoch: 2/20...  Training Step: 330...  Training loss: 2.1752...  0.4763 sec/batch
# 2.20901
# Epoch: 2/20...  Training Step: 331...  Training loss: 2.2090...  0.4766 sec/batch
# 2.19605
# Epoch: 2/20...  Training Step: 332...  Training loss: 2.1961...  0.4762 sec/batch
# 2.17719
# Epoch: 2/20...  Training Step: 333...  Training loss: 2.1772...  0.4755 sec/batch
# 2.19129
# Epoch: 2/20...  Training Step: 334...  Training loss: 2.1913...  0.4773 sec/batch
# 2.1845
# Epoch: 2/20...  Training Step: 335...  Training loss: 2.1845...  0.4760 sec/batch
# 2.18378
# Epoch: 2/20...  Training Step: 336...  Training loss: 2.1838...  0.4770 sec/batch
# 2.22081
# Epoch: 2/20...  Training Step: 337...  Training loss: 2.2208...  0.4767 sec/batch
# 2.17412
# Epoch: 2/20...  Training Step: 338...  Training loss: 2.1741...  0.4770 sec/batch
# 2.19073
# Epoch: 2/20...  Training Step: 339...  Training loss: 2.1907...  0.4767 sec/batch
# 2.16786
# Epoch: 2/20...  Training Step: 340...  Training loss: 2.1679...  0.4765 sec/batch
# 2.18685
# Epoch: 2/20...  Training Step: 341...  Training loss: 2.1868...  0.4762 sec/batch
# 2.16949
# Epoch: 2/20...  Training Step: 342...  Training loss: 2.1695...  0.4761 sec/batch
# 2.16003
# Epoch: 2/20...  Training Step: 343...  Training loss: 2.1600...  0.4758 sec/batch
# 2.18807
# Epoch: 2/20...  Training Step: 344...  Training loss: 2.1881...  0.4764 sec/batch
# 2.18244
# Epoch: 2/20...  Training Step: 345...  Training loss: 2.1824...  0.4767 sec/batch
# 2.19471
# Epoch: 2/20...  Training Step: 346...  Training loss: 2.1947...  0.4767 sec/batch
# 2.16664
# Epoch: 2/20...  Training Step: 347...  Training loss: 2.1666...  0.4768 sec/batch
# 2.15412
# Epoch: 2/20...  Training Step: 348...  Training loss: 2.1541...  0.4765 sec/batch
# 2.17773
# Epoch: 2/20...  Training Step: 349...  Training loss: 2.1777...  0.4767 sec/batch
# 2.20266
# Epoch: 2/20...  Training Step: 350...  Training loss: 2.2027...  0.4765 sec/batch
# 2.1753
# Epoch: 2/20...  Training Step: 351...  Training loss: 2.1753...  0.4756 sec/batch
# 2.18329
# Epoch: 2/20...  Training Step: 352...  Training loss: 2.1833...  0.4759 sec/batch
# 2.15751
# Epoch: 2/20...  Training Step: 353...  Training loss: 2.1575...  0.4763 sec/batch
# 2.15302
# Epoch: 2/20...  Training Step: 354...  Training loss: 2.1530...  0.4759 sec/batch
# 2.14764
# Epoch: 2/20...  Training Step: 355...  Training loss: 2.1476...  0.4762 sec/batch
# 2.15538
# Epoch: 2/20...  Training Step: 356...  Training loss: 2.1554...  0.4765 sec/batch
# 2.12889
# Epoch: 2/20...  Training Step: 357...  Training loss: 2.1289...  0.4765 sec/batch
# 2.19521
# Epoch: 2/20...  Training Step: 358...  Training loss: 2.1952...  0.4764 sec/batch
# 2.16079
# Epoch: 2/20...  Training Step: 359...  Training loss: 2.1608...  0.4760 sec/batch
# 2.14251
# Epoch: 2/20...  Training Step: 360...  Training loss: 2.1425...  0.4759 sec/batch
# 2.15083
# Epoch: 2/20...  Training Step: 361...  Training loss: 2.1508...  0.4762 sec/batch
# 2.15958
# Epoch: 2/20...  Training Step: 362...  Training loss: 2.1596...  0.4760 sec/batch
# 2.154
# Epoch: 2/20...  Training Step: 363...  Training loss: 2.1540...  0.4763 sec/batch
# 2.1509
# Epoch: 2/20...  Training Step: 364...  Training loss: 2.1509...  0.4760 sec/batch
# 2.15997
# Epoch: 2/20...  Training Step: 365...  Training loss: 2.1600...  0.4763 sec/batch
# 2.16078
# Epoch: 2/20...  Training Step: 366...  Training loss: 2.1608...  0.4764 sec/batch
# 2.12856
# Epoch: 2/20...  Training Step: 367...  Training loss: 2.1286...  0.4763 sec/batch
# 2.12847
# Epoch: 2/20...  Training Step: 368...  Training loss: 2.1285...  0.4770 sec/batch
# 2.12452
# Epoch: 2/20...  Training Step: 369...  Training loss: 2.1245...  0.4765 sec/batch
# 2.13908
# Epoch: 2/20...  Training Step: 370...  Training loss: 2.1391...  0.4776 sec/batch
# 2.16305
# Epoch: 2/20...  Training Step: 371...  Training loss: 2.1631...  0.4760 sec/batch
# 2.1555
# Epoch: 2/20...  Training Step: 372...  Training loss: 2.1555...  0.4769 sec/batch
# 2.15217
# Epoch: 2/20...  Training Step: 373...  Training loss: 2.1522...  0.4770 sec/batch
# 2.13321
# Epoch: 2/20...  Training Step: 374...  Training loss: 2.1332...  0.4763 sec/batch
# 2.11788
# Epoch: 2/20...  Training Step: 375...  Training loss: 2.1179...  0.4764 sec/batch
# 2.13464
# Epoch: 2/20...  Training Step: 376...  Training loss: 2.1346...  0.4763 sec/batch
# 2.10646
# Epoch: 2/20...  Training Step: 377...  Training loss: 2.1065...  0.4763 sec/batch
# 2.09252
# Epoch: 2/20...  Training Step: 378...  Training loss: 2.0925...  0.4764 sec/batch
# 2.09464
# Epoch: 2/20...  Training Step: 379...  Training loss: 2.0946...  0.4782 sec/batch
# 2.12283
# Epoch: 2/20...  Training Step: 380...  Training loss: 2.1228...  0.4763 sec/batch
# 2.12231
# Epoch: 2/20...  Training Step: 381...  Training loss: 2.1223...  0.4760 sec/batch
# 2.12944
# Epoch: 2/20...  Training Step: 382...  Training loss: 2.1294...  0.4766 sec/batch
# 2.12099
# Epoch: 2/20...  Training Step: 383...  Training loss: 2.1210...  0.4763 sec/batch
# 2.10331
# Epoch: 2/20...  Training Step: 384...  Training loss: 2.1033...  0.4761 sec/batch
# 2.10593
# Epoch: 2/20...  Training Step: 385...  Training loss: 2.1059...  0.4762 sec/batch
# 2.09607
# Epoch: 2/20...  Training Step: 386...  Training loss: 2.0961...  0.4760 sec/batch
# 2.09587
# Epoch: 2/20...  Training Step: 387...  Training loss: 2.0959...  0.4758 sec/batch
# 2.10977
# Epoch: 2/20...  Training Step: 388...  Training loss: 2.1098...  0.4760 sec/batch
# 2.11398
# Epoch: 2/20...  Training Step: 389...  Training loss: 2.1140...  0.4765 sec/batch
# 2.08443
# Epoch: 2/20...  Training Step: 390...  Training loss: 2.0844...  0.4758 sec/batch
# 2.10518
# Epoch: 2/20...  Training Step: 391...  Training loss: 2.1052...  0.4768 sec/batch
# 2.09598
# Epoch: 2/20...  Training Step: 392...  Training loss: 2.0960...  0.4769 sec/batch
# 2.07804
# Epoch: 2/20...  Training Step: 393...  Training loss: 2.0780...  0.4762 sec/batch
# 2.09725
# Epoch: 2/20...  Training Step: 394...  Training loss: 2.0973...  0.4759 sec/batch
# 2.09786
# Epoch: 2/20...  Training Step: 395...  Training loss: 2.0979...  0.4761 sec/batch
# 2.08221
# Epoch: 2/20...  Training Step: 396...  Training loss: 2.0822...  0.4767 sec/batch
# 2.17011
# Epoch: 3/20...  Training Step: 397...  Training loss: 2.1701...  0.4758 sec/batch
# 2.06427
# Epoch: 3/20...  Training Step: 398...  Training loss: 2.0643...  0.4763 sec/batch
# 2.06685
# Epoch: 3/20...  Training Step: 399...  Training loss: 2.0668...  0.4764 sec/batch
# 2.0737
# Epoch: 3/20...  Training Step: 400...  Training loss: 2.0737...  0.4781 sec/batch
# 2.0815
# Epoch: 3/20...  Training Step: 401...  Training loss: 2.0815...  0.4768 sec/batch
# 2.05425
# Epoch: 3/20...  Training Step: 402...  Training loss: 2.0542...  0.4762 sec/batch
# 2.08189
# Epoch: 3/20...  Training Step: 403...  Training loss: 2.0819...  0.4760 sec/batch
# 2.08553
# Epoch: 3/20...  Training Step: 404...  Training loss: 2.0855...  0.4771 sec/batch
# 2.10523
# Epoch: 3/20...  Training Step: 405...  Training loss: 2.1052...  0.4758 sec/batch
# 2.0848
# Epoch: 3/20...  Training Step: 406...  Training loss: 2.0848...  0.4761 sec/batch
# 2.06747
# Epoch: 3/20...  Training Step: 407...  Training loss: 2.0675...  0.4783 sec/batch
# 2.05663
# Epoch: 3/20...  Training Step: 408...  Training loss: 2.0566...  0.4763 sec/batch
# 2.07503
# Epoch: 3/20...  Training Step: 409...  Training loss: 2.0750...  0.4764 sec/batch
# 2.11104
# Epoch: 3/20...  Training Step: 410...  Training loss: 2.1110...  0.4762 sec/batch
# 2.06409
# Epoch: 3/20...  Training Step: 411...  Training loss: 2.0641...  0.4756 sec/batch
# 2.05781
# Epoch: 3/20...  Training Step: 412...  Training loss: 2.0578...  0.4762 sec/batch
# 2.06888
# Epoch: 3/20...  Training Step: 413...  Training loss: 2.0689...  0.4769 sec/batch
# 2.11044
# Epoch: 3/20...  Training Step: 414...  Training loss: 2.1104...  0.4757 sec/batch
# 2.07285
# Epoch: 3/20...  Training Step: 415...  Training loss: 2.0728...  0.4758 sec/batch
# 2.0736
# Epoch: 3/20...  Training Step: 416...  Training loss: 2.0736...  0.4765 sec/batch
# 2.06677
# Epoch: 3/20...  Training Step: 417...  Training loss: 2.0668...  0.4764 sec/batch
# 2.10733
# Epoch: 3/20...  Training Step: 418...  Training loss: 2.1073...  0.4761 sec/batch
# 2.07034
# Epoch: 3/20...  Training Step: 419...  Training loss: 2.0703...  0.4761 sec/batch
# 2.05254
# Epoch: 3/20...  Training Step: 420...  Training loss: 2.0525...  0.4763 sec/batch
# 2.06518
# Epoch: 3/20...  Training Step: 421...  Training loss: 2.0652...  0.4760 sec/batch
# 2.0303
# Epoch: 3/20...  Training Step: 422...  Training loss: 2.0303...  0.4760 sec/batch
# 2.03183
# Epoch: 3/20...  Training Step: 423...  Training loss: 2.0318...  0.4756 sec/batch
# 2.07145
# Epoch: 3/20...  Training Step: 424...  Training loss: 2.0715...  0.4765 sec/batch
# 2.08645
# Epoch: 3/20...  Training Step: 425...  Training loss: 2.0864...  0.4765 sec/batch
# 2.06421
# Epoch: 3/20...  Training Step: 426...  Training loss: 2.0642...  0.4761 sec/batch
# 2.05697
# Epoch: 3/20...  Training Step: 427...  Training loss: 2.0570...  0.4770 sec/batch
# 2.031
# Epoch: 3/20...  Training Step: 428...  Training loss: 2.0310...  0.4763 sec/batch
# 2.05452
# Epoch: 3/20...  Training Step: 429...  Training loss: 2.0545...  0.4757 sec/batch
# 2.08526
# Epoch: 3/20...  Training Step: 430...  Training loss: 2.0853...  0.4764 sec/batch
# 2.03048
# Epoch: 3/20...  Training Step: 431...  Training loss: 2.0305...  0.4762 sec/batch
# 2.03722
# Epoch: 3/20...  Training Step: 432...  Training loss: 2.0372...  0.4759 sec/batch
# 2.04215
# Epoch: 3/20...  Training Step: 433...  Training loss: 2.0421...  0.4767 sec/batch
# 2.00123
# Epoch: 3/20...  Training Step: 434...  Training loss: 2.0012...  0.4762 sec/batch
# 2.00781
# Epoch: 3/20...  Training Step: 435...  Training loss: 2.0078...  0.4767 sec/batch
# 2.00617
# Epoch: 3/20...  Training Step: 436...  Training loss: 2.0062...  0.4762 sec/batch
# 2.02024
# Epoch: 3/20...  Training Step: 437...  Training loss: 2.0202...  0.4757 sec/batch
# 2.03501
# Epoch: 3/20...  Training Step: 438...  Training loss: 2.0350...  0.4758 sec/batch
# 2.01542
# Epoch: 3/20...  Training Step: 439...  Training loss: 2.0154...  0.4761 sec/batch
# 2.0065
# Epoch: 3/20...  Training Step: 440...  Training loss: 2.0065...  0.4757 sec/batch
# 2.04156
# Epoch: 3/20...  Training Step: 441...  Training loss: 2.0416...  0.4765 sec/batch
# 1.98291
# Epoch: 3/20...  Training Step: 442...  Training loss: 1.9829...  0.4761 sec/batch
# 2.03555
# Epoch: 3/20...  Training Step: 443...  Training loss: 2.0356...  0.4762 sec/batch
# 2.00258
# Epoch: 3/20...  Training Step: 444...  Training loss: 2.0026...  0.4764 sec/batch
# 2.02511
# Epoch: 3/20...  Training Step: 445...  Training loss: 2.0251...  0.4762 sec/batch
# 2.05252
# Epoch: 3/20...  Training Step: 446...  Training loss: 2.0525...  0.4762 sec/batch
# 1.99686
# Epoch: 3/20...  Training Step: 447...  Training loss: 1.9969...  0.4760 sec/batch
# 2.06077
# Epoch: 3/20...  Training Step: 448...  Training loss: 2.0608...  0.4757 sec/batch
# 2.00626
# Epoch: 3/20...  Training Step: 449...  Training loss: 2.0063...  0.4765 sec/batch
# 2.02087
# Epoch: 3/20...  Training Step: 450...  Training loss: 2.0209...  0.4764 sec/batch
# 2.00532
# Epoch: 3/20...  Training Step: 451...  Training loss: 2.0053...  0.4760 sec/batch
# 2.0219
# Epoch: 3/20...  Training Step: 452...  Training loss: 2.0219...  0.4758 sec/batch
# 2.01671
# Epoch: 3/20...  Training Step: 453...  Training loss: 2.0167...  0.4765 sec/batch
# 2.00846
# Epoch: 3/20...  Training Step: 454...  Training loss: 2.0085...  0.4766 sec/batch
# 1.996
# Epoch: 3/20...  Training Step: 455...  Training loss: 1.9960...  0.4760 sec/batch
# 2.0455
# Epoch: 3/20...  Training Step: 456...  Training loss: 2.0455...  0.4765 sec/batch
# 2.00824
# Epoch: 3/20...  Training Step: 457...  Training loss: 2.0082...  0.4763 sec/batch
# 2.04952
# Epoch: 3/20...  Training Step: 458...  Training loss: 2.0495...  0.4764 sec/batch
# 2.04489
# Epoch: 3/20...  Training Step: 459...  Training loss: 2.0449...  0.4763 sec/batch
# 2.01795
# Epoch: 3/20...  Training Step: 460...  Training loss: 2.0179...  0.4760 sec/batch
# 2.00211
# Epoch: 3/20...  Training Step: 461...  Training loss: 2.0021...  0.4758 sec/batch
# 2.03748
# Epoch: 3/20...  Training Step: 462...  Training loss: 2.0375...  0.4759 sec/batch
# 2.03084
# Epoch: 3/20...  Training Step: 463...  Training loss: 2.0308...  0.4763 sec/batch
# 1.98367
# Epoch: 3/20...  Training Step: 464...  Training loss: 1.9837...  0.4767 sec/batch
# 1.99231
# Epoch: 3/20...  Training Step: 465...  Training loss: 1.9923...  0.4765 sec/batch
# 2.00506
# Epoch: 3/20...  Training Step: 466...  Training loss: 2.0051...  0.4773 sec/batch
# 2.04061
# Epoch: 3/20...  Training Step: 467...  Training loss: 2.0406...  0.4772 sec/batch
# 2.01921
# Epoch: 3/20...  Training Step: 468...  Training loss: 2.0192...  0.4763 sec/batch
# 2.02413
# Epoch: 3/20...  Training Step: 469...  Training loss: 2.0241...  0.4768 sec/batch
# 1.98611
# Epoch: 3/20...  Training Step: 470...  Training loss: 1.9861...  0.4764 sec/batch
# 1.99313
# Epoch: 3/20...  Training Step: 471...  Training loss: 1.9931...  0.4763 sec/batch
# 2.02973
# Epoch: 3/20...  Training Step: 472...  Training loss: 2.0297...  0.4758 sec/batch
# 1.99327
# Epoch: 3/20...  Training Step: 473...  Training loss: 1.9933...  0.4761 sec/batch
# 2.00654
# Epoch: 3/20...  Training Step: 474...  Training loss: 2.0065...  0.4763 sec/batch
# 1.95743
# Epoch: 3/20...  Training Step: 475...  Training loss: 1.9574...  0.4764 sec/batch
# 1.97908
# Epoch: 3/20...  Training Step: 476...  Training loss: 1.9791...  0.4768 sec/batch
# 1.954
# Epoch: 3/20...  Training Step: 477...  Training loss: 1.9540...  0.4760 sec/batch
# 2.01291
# Epoch: 3/20...  Training Step: 478...  Training loss: 2.0129...  0.4762 sec/batch
# 1.95352
# Epoch: 3/20...  Training Step: 479...  Training loss: 1.9535...  0.4756 sec/batch
# 1.97734
# Epoch: 3/20...  Training Step: 480...  Training loss: 1.9773...  0.4760 sec/batch
# 1.94733
# Epoch: 3/20...  Training Step: 481...  Training loss: 1.9473...  0.4760 sec/batch
# 1.95472
# Epoch: 3/20...  Training Step: 482...  Training loss: 1.9547...  0.4767 sec/batch
# 1.98001
# Epoch: 3/20...  Training Step: 483...  Training loss: 1.9800...  0.4767 sec/batch
# 1.95584
# Epoch: 3/20...  Training Step: 484...  Training loss: 1.9558...  0.4761 sec/batch
# 1.93902
# Epoch: 3/20...  Training Step: 485...  Training loss: 1.9390...  0.4777 sec/batch
# 1.99212
# Epoch: 3/20...  Training Step: 486...  Training loss: 1.9921...  0.4752 sec/batch
# 1.95659
# Epoch: 3/20...  Training Step: 487...  Training loss: 1.9566...  0.4764 sec/batch
# 1.9694
# Epoch: 3/20...  Training Step: 488...  Training loss: 1.9694...  0.4767 sec/batch
# 1.94252
# Epoch: 3/20...  Training Step: 489...  Training loss: 1.9425...  0.4759 sec/batch
# 1.9461
# Epoch: 3/20...  Training Step: 490...  Training loss: 1.9461...  0.4762 sec/batch
# 1.95058
# Epoch: 3/20...  Training Step: 491...  Training loss: 1.9506...  0.4759 sec/batch
# 1.96295
# Epoch: 3/20...  Training Step: 492...  Training loss: 1.9630...  0.4766 sec/batch
# 1.96422
# Epoch: 3/20...  Training Step: 493...  Training loss: 1.9642...  0.4759 sec/batch
# 1.94877
# Epoch: 3/20...  Training Step: 494...  Training loss: 1.9488...  0.4760 sec/batch
# 1.94431
# Epoch: 3/20...  Training Step: 495...  Training loss: 1.9443...  0.4763 sec/batch
# 1.92589
# Epoch: 3/20...  Training Step: 496...  Training loss: 1.9259...  0.4762 sec/batch
# 1.97737
# Epoch: 3/20...  Training Step: 497...  Training loss: 1.9774...  0.4759 sec/batch
# 1.96069
# Epoch: 3/20...  Training Step: 498...  Training loss: 1.9607...  0.4762 sec/batch
# 1.95026
# Epoch: 3/20...  Training Step: 499...  Training loss: 1.9503...  0.4758 sec/batch
# 1.95061
# Epoch: 3/20...  Training Step: 500...  Training loss: 1.9506...  0.4757 sec/batch
# 1.95202
# Epoch: 3/20...  Training Step: 501...  Training loss: 1.9520...  0.4764 sec/batch
# 1.95394
# Epoch: 3/20...  Training Step: 502...  Training loss: 1.9539...  0.4766 sec/batch
# 1.95531
# Epoch: 3/20...  Training Step: 503...  Training loss: 1.9553...  0.4767 sec/batch
# 1.96942
# Epoch: 3/20...  Training Step: 504...  Training loss: 1.9694...  0.4764 sec/batch
# 1.96411
# Epoch: 3/20...  Training Step: 505...  Training loss: 1.9641...  0.4757 sec/batch
# 1.95417
# Epoch: 3/20...  Training Step: 506...  Training loss: 1.9542...  0.4766 sec/batch
# 1.95516
# Epoch: 3/20...  Training Step: 507...  Training loss: 1.9552...  0.4760 sec/batch
# 1.95612
# Epoch: 3/20...  Training Step: 508...  Training loss: 1.9561...  0.4760 sec/batch
# 1.95216
# Epoch: 3/20...  Training Step: 509...  Training loss: 1.9522...  0.4758 sec/batch
# 1.93779
# Epoch: 3/20...  Training Step: 510...  Training loss: 1.9378...  0.4765 sec/batch
# 1.93175
# Epoch: 3/20...  Training Step: 511...  Training loss: 1.9318...  0.4760 sec/batch
# 1.90329
# Epoch: 3/20...  Training Step: 512...  Training loss: 1.9033...  0.4763 sec/batch
# 1.94995
# Epoch: 3/20...  Training Step: 513...  Training loss: 1.9499...  0.4757 sec/batch
# 1.92778
# Epoch: 3/20...  Training Step: 514...  Training loss: 1.9278...  0.4754 sec/batch
# 1.9444
# Epoch: 3/20...  Training Step: 515...  Training loss: 1.9444...  0.4757 sec/batch
# 1.94648
# Epoch: 3/20...  Training Step: 516...  Training loss: 1.9465...  0.4765 sec/batch
# 1.96209
# Epoch: 3/20...  Training Step: 517...  Training loss: 1.9621...  0.4757 sec/batch
# 1.91479
# Epoch: 3/20...  Training Step: 518...  Training loss: 1.9148...  0.4759 sec/batch
# 1.92167
# Epoch: 3/20...  Training Step: 519...  Training loss: 1.9217...  0.4760 sec/batch
# 1.97364
# Epoch: 3/20...  Training Step: 520...  Training loss: 1.9736...  0.4762 sec/batch
# 1.94087
# Epoch: 3/20...  Training Step: 521...  Training loss: 1.9409...  0.4762 sec/batch
# 1.89698
# Epoch: 3/20...  Training Step: 522...  Training loss: 1.8970...  0.4760 sec/batch
# 1.95072
# Epoch: 3/20...  Training Step: 523...  Training loss: 1.9507...  0.4758 sec/batch
# 1.94384
# Epoch: 3/20...  Training Step: 524...  Training loss: 1.9438...  0.4764 sec/batch
# 1.93934
# Epoch: 3/20...  Training Step: 525...  Training loss: 1.9393...  0.4763 sec/batch
# 1.93383
# Epoch: 3/20...  Training Step: 526...  Training loss: 1.9338...  0.4771 sec/batch
# 1.91142
# Epoch: 3/20...  Training Step: 527...  Training loss: 1.9114...  0.4762 sec/batch
# 1.90689
# Epoch: 3/20...  Training Step: 528...  Training loss: 1.9069...  0.4774 sec/batch
# 1.94321
# Epoch: 3/20...  Training Step: 529...  Training loss: 1.9432...  0.4762 sec/batch
# 1.94515
# Epoch: 3/20...  Training Step: 530...  Training loss: 1.9452...  0.4759 sec/batch
# 1.93799
# Epoch: 3/20...  Training Step: 531...  Training loss: 1.9380...  0.4753 sec/batch
# 1.94102
# Epoch: 3/20...  Training Step: 532...  Training loss: 1.9410...  0.4771 sec/batch
# 1.94727
# Epoch: 3/20...  Training Step: 533...  Training loss: 1.9473...  0.4759 sec/batch
# 1.92311
# Epoch: 3/20...  Training Step: 534...  Training loss: 1.9231...  0.4770 sec/batch
# 1.96521
# Epoch: 3/20...  Training Step: 535...  Training loss: 1.9652...  0.4762 sec/batch
# 1.91432
# ...
# 1.77844
# Epoch: 4/20...  Training Step: 738...  Training loss: 1.7784...  0.4763 sec/batch
# 1.74898
# Epoch: 4/20...  Training Step: 739...  Training loss: 1.7490...  0.4763 sec/batch
# 1.77232
# Epoch: 4/20...  Training Step: 740...  Training loss: 1.7723...  0.4762 sec/batch
# 1.78355
# Epoch: 4/20...  Training Step: 741...  Training loss: 1.7836...  0.4763 sec/batch
# 1.80116
# Epoch: 4/20...  Training Step: 742...  Training loss: 1.8012...  0.4760 sec/batch
# 1.77479
# Epoch: 4/20...  Training Step: 743...  Training loss: 1.7748...  0.4768 sec/batch
# 1.76215
# Epoch: 4/20...  Training Step: 744...  Training loss: 1.7622...  0.4763 sec/batch
# 1.74016
# Epoch: 4/20...  Training Step: 745...  Training loss: 1.7402...  0.4770 sec/batch
# 1.77138
# Epoch: 4/20...  Training Step: 746...  Training loss: 1.7714...  0.4780 sec/batch
# 1.78809
# Epoch: 4/20...  Training Step: 747...  Training loss: 1.7881...  0.4769 sec/batch
# 1.76304
# Epoch: 4/20...  Training Step: 748...  Training loss: 1.7630...  0.4760 sec/batch
# 1.757
# Epoch: 4/20...  Training Step: 749...  Training loss: 1.7570...  0.4764 sec/batch
# 1.76202
# Epoch: 4/20...  Training Step: 750...  Training loss: 1.7620...  0.4760 sec/batch
# 1.77933
# Epoch: 4/20...  Training Step: 751...  Training loss: 1.7793...  0.4766 sec/batch
# 1.75803
# Epoch: 4/20...  Training Step: 752...  Training loss: 1.7580...  0.4761 sec/batch
# 1.72726
# Epoch: 4/20...  Training Step: 753...  Training loss: 1.7273...  0.4758 sec/batch
# 1.79067
# Epoch: 4/20...  Training Step: 754...  Training loss: 1.7907...  0.4762 sec/batch
# 1.78568
# Epoch: 4/20...  Training Step: 755...  Training loss: 1.7857...  0.4759 sec/batch
# 1.75391
# Epoch: 4/20...  Training Step: 756...  Training loss: 1.7539...  0.4768 sec/batch
# 1.77915
# Epoch: 4/20...  Training Step: 757...  Training loss: 1.7792...  0.4763 sec/batch
# 1.76587
# Epoch: 4/20...  Training Step: 758...  Training loss: 1.7659...  0.4763 sec/batch
# 1.75283
# Epoch: 4/20...  Training Step: 759...  Training loss: 1.7528...  0.4760 sec/batch
# 1.74589
# Epoch: 4/20...  Training Step: 760...  Training loss: 1.7459...  0.4762 sec/batch
# 1.76942
# Epoch: 4/20...  Training Step: 761...  Training loss: 1.7694...  0.4761 sec/batch
# 1.81297
# Epoch: 4/20...  Training Step: 762...  Training loss: 1.8130...  0.4759 sec/batch
# 1.75396
# Epoch: 4/20...  Training Step: 763...  Training loss: 1.7540...  0.4763 sec/batch
# 1.7452
# Epoch: 4/20...  Training Step: 764...  Training loss: 1.7452...  0.4761 sec/batch
# 1.74488
# Epoch: 4/20...  Training Step: 765...  Training loss: 1.7449...  0.4759 sec/batch
# 1.744
# Epoch: 4/20...  Training Step: 766...  Training loss: 1.7440...  0.4754 sec/batch
# 1.77665
# Epoch: 4/20...  Training Step: 767...  Training loss: 1.7767...  0.4764 sec/batch
# 1.7686
# Epoch: 4/20...  Training Step: 768...  Training loss: 1.7686...  0.4763 sec/batch
# 1.76349
# Epoch: 4/20...  Training Step: 769...  Training loss: 1.7635...  0.4761 sec/batch
# 1.73702
# Epoch: 4/20...  Training Step: 770...  Training loss: 1.7370...  0.4760 sec/batch
# 1.73099
# Epoch: 4/20...  Training Step: 771...  Training loss: 1.7310...  0.4761 sec/batch
# 1.76628
# Epoch: 4/20...  Training Step: 772...  Training loss: 1.7663...  0.4763 sec/batch
# 1.72216
# Epoch: 4/20...  Training Step: 773...  Training loss: 1.7222...  0.4762 sec/batch
# 1.71646
# Epoch: 4/20...  Training Step: 774...  Training loss: 1.7165...  0.4759 sec/batch
# 1.72811
# Epoch: 4/20...  Training Step: 775...  Training loss: 1.7281...  0.4762 sec/batch
# 1.7558
# Epoch: 4/20...  Training Step: 776...  Training loss: 1.7558...  0.4759 sec/batch
# 1.74725
# Epoch: 4/20...  Training Step: 777...  Training loss: 1.7473...  0.4758 sec/batch
# 1.76207
# Epoch: 4/20...  Training Step: 778...  Training loss: 1.7621...  0.4754 sec/batch
# 1.74825
# Epoch: 4/20...  Training Step: 779...  Training loss: 1.7483...  0.4766 sec/batch
# 1.73226
# Epoch: 4/20...  Training Step: 780...  Training loss: 1.7323...  0.4763 sec/batch
# 1.75096
# Epoch: 4/20...  Training Step: 781...  Training loss: 1.7510...  0.4765 sec/batch
# 1.73103
# Epoch: 4/20...  Training Step: 782...  Training loss: 1.7310...  0.4762 sec/batch
# 1.73392
# Epoch: 4/20...  Training Step: 783...  Training loss: 1.7339...  0.4758 sec/batch
# 1.74498
# Epoch: 4/20...  Training Step: 784...  Training loss: 1.7450...  0.4759 sec/batch
# 1.74865
# Epoch: 4/20...  Training Step: 785...  Training loss: 1.7486...  0.4761 sec/batch
# 1.71885
# Epoch: 4/20...  Training Step: 786...  Training loss: 1.7189...  0.4757 sec/batch
# 1.7494
# Epoch: 4/20...  Training Step: 787...  Training loss: 1.7494...  0.4761 sec/batch
# 1.72297
# Epoch: 4/20...  Training Step: 788...  Training loss: 1.7230...  0.4760 sec/batch
# 1.70887
# Epoch: 4/20...  Training Step: 789...  Training loss: 1.7089...  0.4771 sec/batch
# 1.75226
# Epoch: 4/20...  Training Step: 790...  Training loss: 1.7523...  0.4759 sec/batch
# 1.73212
# Epoch: 4/20...  Training Step: 791...  Training loss: 1.7321...  0.4752 sec/batch
# 1.71711
# Epoch: 4/20...  Training Step: 792...  Training loss: 1.7171...  0.4764 sec/batch
# 1.83799
# Epoch: 5/20...  Training Step: 793...  Training loss: 1.8380...  0.4762 sec/batch
# 1.72451
# Epoch: 5/20...  Training Step: 794...  Training loss: 1.7245...  0.4764 sec/batch
# 1.716
# Epoch: 5/20...  Training Step: 795...  Training loss: 1.7160...  0.4761 sec/batch
# 1.73327
# Epoch: 5/20...  Training Step: 796...  Training loss: 1.7333...  0.4758 sec/batch
# 1.73444
# Epoch: 5/20...  Training Step: 797...  Training loss: 1.7344...  0.4763 sec/batch
# 1.6896
# Epoch: 5/20...  Training Step: 798...  Training loss: 1.6896...  0.4763 sec/batch
# 1.72744
# Epoch: 5/20...  Training Step: 799...  Training loss: 1.7274...  0.4760 sec/batch
# 1.72139
# Epoch: 5/20...  Training Step: 800...  Training loss: 1.7214...  0.4764 sec/batch
# 1.75019
# Epoch: 5/20...  Training Step: 801...  Training loss: 1.7502...  0.4768 sec/batch
# 1.73199
# Epoch: 5/20...  Training Step: 802...  Training loss: 1.7320...  0.4762 sec/batch
# 1.69347
# Epoch: 5/20...  Training Step: 803...  Training loss: 1.6935...  0.4758 sec/batch
# 1.70578
# Epoch: 5/20...  Training Step: 804...  Training loss: 1.7058...  0.4761 sec/batch
# 1.72536
# Epoch: 5/20...  Training Step: 805...  Training loss: 1.7254...  0.4757 sec/batch
# 1.75726
# Epoch: 5/20...  Training Step: 806...  Training loss: 1.7573...  0.4758 sec/batch
# 1.7172
# Epoch: 5/20...  Training Step: 807...  Training loss: 1.7172...  0.4755 sec/batch
# 1.70606
# Epoch: 5/20...  Training Step: 808...  Training loss: 1.7061...  0.4758 sec/batch
# 1.73033
# Epoch: 5/20...  Training Step: 809...  Training loss: 1.7303...  0.4757 sec/batch
# 1.76702
# Epoch: 5/20...  Training Step: 810...  Training loss: 1.7670...  0.4764 sec/batch
# 1.72959
# Epoch: 5/20...  Training Step: 811...  Training loss: 1.7296...  0.4767 sec/batch
# 1.7517
# Epoch: 5/20...  Training Step: 812...  Training loss: 1.7517...  0.4765 sec/batch
# 1.72023
# Epoch: 5/20...  Training Step: 813...  Training loss: 1.7202...  0.4760 sec/batch
# 1.74948
# Epoch: 5/20...  Training Step: 814...  Training loss: 1.7495...  0.4762 sec/batch
# 1.72377
# Epoch: 5/20...  Training Step: 815...  Training loss: 1.7238...  0.4759 sec/batch
# 1.71891
# Epoch: 5/20...  Training Step: 816...  Training loss: 1.7189...  0.4760 sec/batch
# 1.73134
# Epoch: 5/20...  Training Step: 817...  Training loss: 1.7313...  0.4766 sec/batch
# 1.69141
# Epoch: 5/20...  Training Step: 818...  Training loss: 1.6914...  0.4767 sec/batch
# 1.68325
# Epoch: 5/20...  Training Step: 819...  Training loss: 1.6832...  0.4768 sec/batch
# 1.73687
# Epoch: 5/20...  Training Step: 820...  Training loss: 1.7369...  0.4762 sec/batch
# 1.75278
# Epoch: 5/20...  Training Step: 821...  Training loss: 1.7528...  0.4761 sec/batch
# 1.73528
# Epoch: 5/20...  Training Step: 822...  Training loss: 1.7353...  0.4761 sec/batch
# 1.71952
# Epoch: 5/20...  Training Step: 823...  Training loss: 1.7195...  0.4758 sec/batch
# 1.68817
# Epoch: 5/20...  Training Step: 824...  Training loss: 1.6882...  0.4760 sec/batch
# 1.72445
# Epoch: 5/20...  Training Step: 825...  Training loss: 1.7244...  0.4768 sec/batch
# 1.74261
# Epoch: 5/20...  Training Step: 826...  Training loss: 1.7426...  0.4762 sec/batch
# 1.71015
# Epoch: 5/20...  Training Step: 827...  Training loss: 1.7101...  0.4762 sec/batch
# 1.70443
# Epoch: 5/20...  Training Step: 828...  Training loss: 1.7044...  0.4760 sec/batch
# 1.69335
# Epoch: 5/20...  Training Step: 829...  Training loss: 1.6933...  0.4750 sec/batch
# 1.67687
# Epoch: 5/20...  Training Step: 830...  Training loss: 1.6769...  0.4760 sec/batch
# 1.66687
# Epoch: 5/20...  Training Step: 831...  Training loss: 1.6669...  0.4764 sec/batch
# 1.67942
# Epoch: 5/20...  Training Step: 832...  Training loss: 1.6794...  0.4759 sec/batch
# 1.68649
# Epoch: 5/20...  Training Step: 833...  Training loss: 1.6865...  0.4763 sec/batch
# 1.72109
# Epoch: 5/20...  Training Step: 834...  Training loss: 1.7211...  0.4759 sec/batch
# 1.68657
# Epoch: 5/20...  Training Step: 835...  Training loss: 1.6866...  0.4764 sec/batch
# 1.66511
# Epoch: 5/20...  Training Step: 836...  Training loss: 1.6651...  0.4764 sec/batch
# 1.72374
# Epoch: 5/20...  Training Step: 837...  Training loss: 1.7237...  0.4764 sec/batch
# 1.66309
# Epoch: 5/20...  Training Step: 838...  Training loss: 1.6631...  0.4760 sec/batch
# 1.70607
# Epoch: 5/20...  Training Step: 839...  Training loss: 1.7061...  0.4763 sec/batch
# 1.68699
# Epoch: 5/20...  Training Step: 840...  Training loss: 1.6870...  0.4764 sec/batch
# 1.69156
# Epoch: 5/20...  Training Step: 841...  Training loss: 1.6916...  0.4764 sec/batch
# 1.74007
# Epoch: 5/20...  Training Step: 842...  Training loss: 1.7401...  0.4764 sec/batch
# 1.68004
# Epoch: 5/20...  Training Step: 843...  Training loss: 1.6800...  0.4762 sec/batch
# 1.75294
# Epoch: 5/20...  Training Step: 844...  Training loss: 1.7529...  0.4759 sec/batch
# 1.69418
# Epoch: 5/20...  Training Step: 845...  Training loss: 1.6942...  0.4766 sec/batch
# 1.70517
# Epoch: 5/20...  Training Step: 846...  Training loss: 1.7052...  0.4768 sec/batch
# 1.69062
# Epoch: 5/20...  Training Step: 847...  Training loss: 1.6906...  0.4763 sec/batch
# 1.70556
# Epoch: 5/20...  Training Step: 848...  Training loss: 1.7056...  0.4762 sec/batch
# 1.73207
# Epoch: 5/20...  Training Step: 849...  Training loss: 1.7321...  0.4759 sec/batch
# 1.69264
# Epoch: 5/20...  Training Step: 850...  Training loss: 1.6926...  0.4760 sec/batch
# 1.67758
# Epoch: 5/20...  Training Step: 851...  Training loss: 1.6776...  0.4761 sec/batch
# 1.73601
# Epoch: 5/20...  Training Step: 852...  Training loss: 1.7360...  0.4760 sec/batch
# 1.7023
# Epoch: 5/20...  Training Step: 853...  Training loss: 1.7023...  0.4758 sec/batch
# 1.75572
# Epoch: 5/20...  Training Step: 854...  Training loss: 1.7557...  0.4759 sec/batch
# 1.73168
# Epoch: 5/20...  Training Step: 855...  Training loss: 1.7317...  0.4765 sec/batch
# 1.72125
# Epoch: 5/20...  Training Step: 856...  Training loss: 1.7212...  0.4765 sec/batch
# 1.69377
# Epoch: 5/20...  Training Step: 857...  Training loss: 1.6938...  0.4763 sec/batch
# 1.73101
# Epoch: 5/20...  Training Step: 858...  Training loss: 1.7310...  0.4759 sec/batch
# 1.71908
# Epoch: 5/20...  Training Step: 859...  Training loss: 1.7191...  0.4762 sec/batch
# 1.68575
# Epoch: 5/20...  Training Step: 860...  Training loss: 1.6858...  0.4762 sec/batch
# 1.70127
# Epoch: 5/20...  Training Step: 861...  Training loss: 1.7013...  0.4763 sec/batch
# 1.69141
# Epoch: 5/20...  Training Step: 862...  Training loss: 1.6914...  0.4757 sec/batch
# 1.74582
# Epoch: 5/20...  Training Step: 863...  Training loss: 1.7458...  0.4766 sec/batch
# 1.71807
# Epoch: 5/20...  Training Step: 864...  Training loss: 1.7181...  0.4757 sec/batch
# 1.72528
# Epoch: 5/20...  Training Step: 865...  Training loss: 1.7253...  0.4755 sec/batch
# 1.67399
# Epoch: 5/20...  Training Step: 866...  Training loss: 1.6740...  0.4758 sec/batch
# 1.68852
# Epoch: 5/20...  Training Step: 867...  Training loss: 1.6885...  0.4763 sec/batch
# 1.72563
# Epoch: 5/20...  Training Step: 868...  Training loss: 1.7256...  0.4766 sec/batch
# 1.68926
# Epoch: 5/20...  Training Step: 869...  Training loss: 1.6893...  0.4757 sec/batch
# 1.70092
# Epoch: 5/20...  Training Step: 870...  Training loss: 1.7009...  0.4760 sec/batch
# 1.65198
# Epoch: 5/20...  Training Step: 871...  Training loss: 1.6520...  0.4762 sec/batch
# 1.68091
# Epoch: 5/20...  Training Step: 872...  Training loss: 1.6809...  0.4762 sec/batch
# 1.65081
# Epoch: 5/20...  Training Step: 873...  Training loss: 1.6508...  0.4765 sec/batch
# 1.70513
# Epoch: 5/20...  Training Step: 874...  Training loss: 1.7051...  0.4758 sec/batch
# 1.65034
# Epoch: 5/20...  Training Step: 875...  Training loss: 1.6503...  0.4761 sec/batch
# 1.68799
# Epoch: 5/20...  Training Step: 876...  Training loss: 1.6880...  0.4762 sec/batch
# 1.65857
# Epoch: 5/20...  Training Step: 877...  Training loss: 1.6586...  0.4764 sec/batch
# 1.67481
# Epoch: 5/20...  Training Step: 878...  Training loss: 1.6748...  0.4760 sec/batch
# 1.67095
# Epoch: 5/20...  Training Step: 879...  Training loss: 1.6710...  0.4762 sec/batch
# 1.67287
# Epoch: 5/20...  Training Step: 880...  Training loss: 1.6729...  0.4760 sec/batch
# 1.63688
# Epoch: 5/20...  Training Step: 881...  Training loss: 1.6369...  0.4761 sec/batch
# 1.69204
# Epoch: 5/20...  Training Step: 882...  Training loss: 1.6920...  0.4758 sec/batch
# 1.65138
# Epoch: 5/20...  Training Step: 883...  Training loss: 1.6514...  0.4766 sec/batch
# 1.66578
# Epoch: 5/20...  Training Step: 884...  Training loss: 1.6658...  0.4770 sec/batch
# 1.65971
# Epoch: 5/20...  Training Step: 885...  Training loss: 1.6597...  0.4763 sec/batch
# 1.66045
# Epoch: 5/20...  Training Step: 886...  Training loss: 1.6604...  0.4759 sec/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-b9e928959145> in <module>()
#      28                                                  model.final_state,
#      29                                                  model.optimizer],
# ---> 30                                                  feed_dict=feed)
#      31             print(batch_loss)
#      32             end = time.time()
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# #### Saved checkpoints
#
# Read up on saving and loading checkpoints here: https://www.tensorflow.org/programmers_guide/variables

# %%
tf.train.get_checkpoint_state('checkpoints')
# Out:
# model_checkpoint_path: "checkpoints/i3960_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3960_l512.ckpt"

# %% [markdown]
# ## Sampling
#
# Now that the network is trained, we'll can use it to generate new text. The idea is that we pass in a character, then the network will predict the next character. We can use the new one, to predict the next one. And we keep doing this to generate all new text. I also included some functionality to prime the network with some text by passing in a string and building up a state from that.
#
# The network gives us predictions for each character. To reduce noise and make things a little less random, I'm going to only choose a new character from the top N most likely characters.

# %%
def pick_top_n(preds, vocab_size, top_n=5):
    p = np.squeeze(preds)
    p[np.argsort(p)[:-top_n]] = 0
    p = p / np.sum(p)
    c = np.random.choice(vocab_size, 1, p=p)[0]
    return c

# %%
def sample(checkpoint, n_samples, lstm_size, vocab_size, prime="The "):
    samples = [c for c in prime]
    model = CharRNN(len(vocab), lstm_size=lstm_size, sampling=True)
    saver = tf.train.Saver()
    with tf.Session() as sess:
        saver.restore(sess, checkpoint)
        new_state = sess.run(model.initial_state)
        for c in prime:
            x = np.zeros((1, 1))
            x[0,0] = vocab_to_int[c]
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

        c = pick_top_n(preds, len(vocab))
        samples.append(int_to_vocab[c])

        for i in range(n_samples):
            x[0,0] = c
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

            c = pick_top_n(preds, len(vocab))
            samples.append(int_to_vocab[c])
        
    return ''.join(samples)

# %% [markdown]
# Here, pass in the path to a checkpoint and sample from the network.

# %%
tf.train.latest_checkpoint('checkpoints')
# Out:
# 'checkpoints/i3960_l512.ckpt'

# %%
checkpoint = tf.train.latest_checkpoint('checkpoints')
samp = sample(checkpoint, 2000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# Farens. The man and this presence there was a long whell against the
# serfice. And she would have seen a dest of sorry of any arrangements,
# true. But the side house was in the money about the chief same, and
# that he had to say to all his face, with some significance for his wife
# that he had come and done to the penslition of a little and sounds of
# the society, and always was in her and horses, and that that they
# could not be a chalacteristic on her so second become in her soul that it
# was all sincerity, and her clothest having been talking to horror of
# a presine that was something was all his mother had no station.
#
# The conversation had suddenly had not been anything.
#
# Sometying her health she came over the services, had sat down again, and
# at the conversation was not in the strange shreed to the door, and with
# his sight of the party, the sick man thinking the secret of the mother
# when they had brought a humored friends, and the prayers that he could not
# let him any more and marking this subject, and they. The most of the
# steps about indeed and triude of accordance of the position that was
# steping himself. They went to those on its ordered and could only to
# chart how when they all and the more angry and the sight about it. The
# peasants would his chillish accounts and at the partious feeling of
# particularly ares, and so thore was some shorting or them. And he so
# see the place, who was seeing that something coughed hands, as though
# he was at the same, was not that she was insulted. Anna had been at
# the prince tell out his hat this article and to begin to say.
#
# "Yive were a selvated the members who have taken the station in which the
# committee? And is to darling a minutate of the carriage of marnated. I have
# took to myself in the steps and a single morn and happy.
#
# "If that's into a single morning, this seems thanks to her and thinks
# in the past and married that." The side had been carrying all the
# portrait of his words. These wires he was sitting at the past of the
# room, t

# %%
checkpoint = 'checkpoints/i200_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# Fard,. ""
# I"
# "The tat he winse he wos al alt ong the hor an thot hed the
# the sin the sand we he sos and se th the an soris he as oth thes sosed to he the he ad ond on har soron sha sas sitis he
# sentes the he wis as arton thir ans on ond wome to whe the sos thes sosit to the sos at hos ho she sis the she him an tot thes th an setit and wo he angeras,. Tho hor ho wot thime
# ne tot ha to we we he won thar al thir send tougtint ting and wh wamed, the the her what hot wit he wat ta hor,
# thing th whe tousederede sad sithe the the he se the han shes oress ho tot on here an on ot to he the hhressasesid thise where ans andentor tat the
# t the won he ans te hite wost hin sos torinnd
# tare wes to se her
# inntor ond tot ont ate
# silt wens
# thithe serede ho he the soros, sers on asis and af on he tare sin hos tot this won oth the he tins, and ang tee ar the ant oud thot woth shat ha lan and sithe to she sos thoth sar te sesilt ther singetin to he te artor to ho he
# wans he ans her han ase and.
# I hind wasd we

# %%
checkpoint = 'checkpoints/i600_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# Farnt out a seenen a doons the werly a prostines, bet of to as sone him, al her his and and she had booke word and wert on her had and said to hoult, sto stat to she whon he wond to
# denting andond to stat had he he seed a sele to the corsions.
#
# "The more when she shead, thourg that so he had and to the sort, sunding him his and and sace and where her
# headed he said
# the haress and than sheard her, her has thing his stalith his tongenter," she said
# he dasted the monting the sond of
# their that allong her ald
# have a tare him that to the somesily wourd to dive in and som her and whene the sead, and withon te said whine and had sail he having had
# same to sime her has
# antanter that
# she she distlidion of her heally.
#
# "When, an the pinter on atone with
# the pasting, and sooked hus a sant of her his her ander was having to the panting to shingher at a shiss to thow to and walk nover as to the portanion," said Stepan'Akknavitcch with which all she coundsess in this his,
# boring the panitiou, and
# atonge

# %%
checkpoint = 'checkpoints/i1200_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# Farcial the
# confiring to the mone of the correm and thinds. She
# she saw the
# streads of herself hand only astended of the carres to her his some of the princess of which he came him of
# all that his white the dreasing of
# thisking the princess and with she was she had
# bettee a still and he was happined, with the pood on the mush to the peaters and seet it.
#
# "The possess a streatich, the may were notine at his mate a misted
# and the
# man of the mother at the same of the seem her
# felt. He had not here.
#
# "I conest only be alw you thinking that the partion
# of their said."
#
# "A much then you make all her
# somether. Hower their centing
# about
# this, and I won't give it in
# himself.
# I had not come at any see it will that there she chile no one that him.
#
# "The distiction with you all.... It was
# a mone of the mind were starding to the simple to a mone. It to be to ser in the place," said Vronsky.
# "And a plais in
# his face, has alled in the consess on at they to gan in the sint
# at as that
# he would not be and t
